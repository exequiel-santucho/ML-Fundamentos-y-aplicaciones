# %% [markdown]
# # Presentación del Problema: Identificación binaria de Razas de Perros
#
# Identificar razas de perros es un problema interesante de computer vision debido a las pequeñas diferencias visuales que separan una raza de otra. Durante este ejercicio se trabajará con la base de datos de raza de perros de Kaggle (https://www.kaggle.com/c/dog-breed-identification/data) ya cargados y separados en train y test.
#
# ## Tarea del modelo
# La tarea a realizar será la clasificación binaria de diferentes imágenes de perros solamente en dos razas distintas.
#
# ## Objetivos del ejercicio
# El objetivo del ejercicio es que, partiendo de una base de datos, con un preprocesamiento de imágenes y arquitectura de una red dada, los alumnos sean capaces de mejorar el resultado mediante técnicas de optimización, que pueden incluir modificar la arquitectura de la red.
#
# ## Estructura del Notebook
# La estructura del presente Notebook está dividida en las siguientes secciones
#
# 1.   Operaciones iniciales para trabajar con los archivos de Drive
# 2.   Preprocesamiento de los datos de entrada
# 3.   Arquitectura de la red propuesta
# 4.   Propuestas de mejora
#
# ## Base de Datos
# La base de datos original consta de alrededor de 20.500 imágenes de perros, clasificadas en 120 razas diferentes, divididas al 50 % en training y test.
# Durante el ejercicio se trabajará solo con 2 razas de perros elegidas al azar, Golder Retrievers y Pastores escoceses, para enfocarnos en la tarea de clasificación binaria.
#
# Se debe tener en cuenta que las imágenes de la base de datos están etiquetadas solamente por un id, y realiza el mapeo de la raza a través de un archivo CSV.

# %% [markdown]
# ## Operaciones Iniciales
#
# En primer lugar, al tener las imágenes de entrenamiento y test cargadas en el Drive, este debe ser montado sobre el Notebook para poder ser utilizado, lo que se hace con la celda siguiente.
#
# Al correr la celda aparecerá un link y un campo para ingresar un código de autorización. Este código se obtendrá al darle autorización a Colab para acceder a Drive mediante el Link, por lo que se debe:
#
# 1. Hacer click en el Link
# 2. Copiar el código de autorización
# 3. Pegarlo en el campo provisto para tal fin
# 4. Apretar Enter
#
# Luego de estos pasos, los archivos del Drive podrán ser utilizados desde el Notebook.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %% [markdown]
# ### Navegar hasta el directorio con las carpetas train y test
#
# Con el drive ya montado, es posible acceder a los archivos mediante comandos de consola, por ejemplo:
# ```
# !ls
# ```
# permite listar información sobre los archivos y carpetas del directorio activo

# %%
# Permite ver el contenido del directorio activo
# !ls
# Out:
# sample_data

# %% [markdown]
# ```
# %cd ruta_objetivo
# ```
# permite navegar por el directorio cambiando de carpeta
#
# Usando estos dos comandos, lo que se debe hacer es:
#
# 1. Posicionarse en el directorio donde se encuentran las carpetas *train* y *test*

# %%
# %cd /gdrive/'My Drive'/'Machine Learning: Fundamentos y Aplicaciones'
# !ls
# Out:
# /gdrive/My Drive/Machine Learning: Fundamentos y Aplicaciones
# '1-Python, Numpy y MNIST.ipynb'   labeled_train  'Proyecto Final.ipynb'   train
# '2- CIFAR10 y CIFAR100.ipynb'	  labels.csv	  test

# %% [markdown]
# ## Preprocesamiento de los datos de entrada
#
# En primer lugar se debe trabajar con los datos para que sean fácilmente utilizables al momento de realizar el entrenamiento y el test. Para ello se realizará lo siguiente:
#
# 1. Crear un diccionario que relacione el id del archivo con la raza correcta.
#
# 2. A partir de él, generar un "diccionario contador", para reemplazar cada nombre de archivo de imágenes por su raza y un número que lo acompañe. Por ejemplo, *Golden_Retriever-1*, *Golden_Retriever-2*, y así sucesivamente.
#
# 3. Guardar las imágenes con estos nuevos nombres de archivo.
#
# 4. Modificar el tamaño de las imágenes para utilizar un tamaño de entrada uniforme.

# %% [markdown]
# #### Importar todos los paquetes a utilizar

# %%
from PIL import Image           # para cargar las imágenes
import numpy as np
import os                       # para navegar por el sistema de archivos
import imageio                  # para escribir imágenes
from random import shuffle      # para aleatorizar la posición de las imágenes
import matplotlib.pyplot as plt # para mostrar las imágenes

# %% [markdown]
# #### Crear el diccionario que relacione el id de la imagen con la raza

# %%
naming_dict = {}                                          # id: raza
f = open("labels.csv", "r")                               # abrir el archivo de labels
fileContents = f.read()
fileContents = fileContents.split('\n')
for i in range(len(fileContents)-1):
  fileContents[i] = fileContents[i].split(',')
  naming_dict[fileContents[i][0]] = fileContents[i][1]
print(naming_dict)
# Out:
# {'id': 'breed', '000bec180eb18c7604dcecc8fe0dba07': 'boston_bull', '001513dfcb2ffafc82cccf4d8bbaba97': 'dingo', '001cdf01b096e06d78e9e5112d419397': 'pekinese', '00214f311d5d2247d5dfe4fe24b2303d': 'bluetick', '0021f9ceb3235effd7fcde7f7538ed62': 'golden_retriever', '002211c81b498ef88e1b40b9abf84e1d': 'bedlington_terrier', '00290d3e1fdd27226ba27a8ce248ce85': 'bedlington_terrier', '002a283a315af96eaea0e28e7163b21b': 'borzoi', '003df8b8a8b05244b1d920bb6cf451f9': 'basenji', '0042188c895a2f14ef64a918ed9c7b64': 'scottish_deerhound', '004396df1acd0f1247b740ca2b14616e': 'shetland_sheepdog', '0067dc3eab0b3c3ef0439477624d85d6': 'walker_hound', '00693b8bc2470375cc744a6391d397ec': 'maltese_dog', '006cc3ddb9dc1bd827479569fcdc52dc': 'bluetick', '0075dc49dab4024d12fafe67074d8a81': 'norfolk_terrier', '00792e341f3c6eb33663e415d0715370': 'african_hunting_dog', '007b5a16db9d9ff9d7ad39982703e429': 'wire-haired_fox_terrier', '007b8a07882822475a4ce6581e70b1f8': 'redbone', '007ff9a78eba2aebb558afea3a51c469': 'lakeland_terrier', '008887054b18ba3c7601792b6a453cc3': 'boxer', '008b1271ed1addaccf93783b39deab45': 'doberman', '008ba178d6dfc1a583617470d19c1673': 'otterhound', '009509be3ca7cce0ff9e37c8b09b1125': 'otterhound', '0097c6242c6f3071762d9f85c3ef1b2f': 'bedlington_terrier', '00a338a92e4e7bf543340dc849230e75': 'dingo', '00a366d4b4a9bbb6c8a63126697b7656': 'golden_retriever', '00a862390341c5be090dd72bd2bc19ef': 'standard_schnauzer', '00b7d114bc5166a629a3cc03d9329120': 'irish_water_spaniel', '00ba244566e36e0af3d979320fd3017f': 'black-and-tan_coonhound', '00bee065dcec471f26394855c5c2f3de': 'cairn', '00ca18751837cd6a22813f8e221f7819': 'affenpinscher', '00cc68a50b2d016a6b29af628ea4e04b': 'labrador_retriever', '00ddcec076073cc96f82c27bf4548fbc': 'ibizan_hound', '00e9ed3fab1d2032603d1a90e557976f': 'english_setter', '00f34ac0a16ef43e6fd1de49a26081ce': 'walker_hound', '00fa641312604199831755f96109fde7': 'weimaraner', '00fda6ecca54efbac26e907be4b0b78b': 'giant_schnauzer', '0100f55e4f0fe28f2c0465d3fc4b9897': 'golden_retriever', '010d65bd29d246aea53d9849da142ccf': 'boston_bull', '010e87fdf252645a827e37470e65e842': 'groenendael', '011761e3ae8ec5e188e8f0bcb59bb8b6': 'lakeland_terrier', '011bd7fd7c036dbb243d0e37329c77b7': 'irish_water_spaniel', '011e06760794850c40f23d6426c40774': 'dhole', '0120343862761d052d6a7ade81625c94': 'dingo', '01268f0007876a692907bda89468184c': 'affenpinscher', '012ff2d21dad14452ea16b4cda7eef4c': 'toy_poodle', '013aed490e0e15a8989e12ae0d0ccfaa': 'border_terrier', '013c43f40f0fb13fa25ac0c2a70fd48f': 'lakeland_terrier', '013f8fdf6d638c7bb042f5f17e8a9fdc': 'tibetan_terrier', '0140b05bfc2fd43f2819fab3d8566109': 'norwegian_elkhound', '014c2b0cd8e3b517e649cecf8543b8fe': 'african_hunting_dog', '0159b6457aac89f43d1c1931cdf7500b': 'irish_water_spaniel', '015b363b062f602e7ec04ce28e640d05': 'walker_hound', '015b4aa50dd9b4a0d26dc0c38f41b489': 'irish_water_spaniel', '015d86b2fcb36f0fdfbe94a66c0e3400': 'wire-haired_fox_terrier', '0161847d5bfae154af084993fa26a1a7': 'giant_schnauzer', '0162107acd8f2588c0944b791d61bb0c': 'affenpinscher', '0162b3e0144fb1d1ab82fbff3ace9938': 'shih-tzu', '01680178ca6664294efb493a46014a82': 'irish_terrier', '0169294085e94d1250587b38e4fbb532': 'kuvasz', '016bcdb05e2d0e0878877df21b8c3cff': 'german_shepherd', '0177a92a906192bfde8adbb8a237e524': 'greater_swiss_mountain_dog', '018aae5768833c34e3df30d63429251e': 'basset', '0192d7174233ebdb3d720000413829ac': 'australian_terrier', '019c92d1ff56deb9d75d809a92bc84d8': 'schipperke', '019ff93e03802e661577b5869e099dcb': 'rhodesian_ridgeback', '01a3b064c56edbe3abf55051b16134d4': 'irish_setter', '01a41985ab8209e750588fa348d635be': 'appenzeller', '01b09bdac592b0eb9909dd105314ad3a': 'german_shepherd', '01b35a06b00e4a832b935cf8d51303c1': 'bloodhound', '01b36cb1b80ab8c3a7d2b7128ad21bdc': 'samoyed', '01b6c2bd3053535a58d8de763cf06aa0': 'miniature_schnauzer', '01b849a7e4fbc545f6b2806cb87ab371': 'brittany_spaniel', '01c230ec18eed427cf5b1db1a833024d': 'english_setter', '01d0f3692e576b3cde511285352aed4a':  ...

# %% [markdown]
# #### Crear el diccionario contador que comience en 0 para cada raza

# %%
breeds = naming_dict.values()
breed_set = set(breeds)         # set: Crea un nuevo conjunto iterable no ordenado a partir de breeds
counting_dict = {}
for i in breed_set:
  counting_dict[i] = 0

# %% [markdown]
# #### Guardar las imágenes con los nuevos nombres de archivo dados por el diccionario para train y test
#
# Paciencia! Puede demorar unos minutos.

# %%
print('Guardando imágenes en labeled_train')
imgNumber = 0
for img in os.listdir('./train'):
  imgNumber = imgNumber + 1
  print('imágenes procesadas: ', imgNumber)
  imgName = img.split('.')[0]               # convierte '0913209.jpg' en '0913209'
  label = naming_dict[str(imgName)]         # obtiene la raza del diccionario
  counting_dict[label] += 1                 # aumenta la cuenta en el contador
  path = os.path.join('./train', img)
  saveName = './labeled_train/' + label + '-' + str(counting_dict[label]) + '.jpg' # nuevo nombre con raza y número
  image_data = np.array(Image.open(path))
  imageio.imwrite(saveName, image_data)     # guarda la imagen con el nuevo nombre
# Out:
# Guardando imágenes en labeled_train
# imágenes procesadas:  1
# imágenes procesadas:  2
# imágenes procesadas:  3
# imágenes procesadas:  4
# imágenes procesadas:  5
# imágenes procesadas:  6
# imágenes procesadas:  7
# imágenes procesadas:  8
# imágenes procesadas:  9
# imágenes procesadas:  10
# imágenes procesadas:  11
# imágenes procesadas:  12
# imágenes procesadas:  13
# imágenes procesadas:  14
# imágenes procesadas:  15
# imágenes procesadas:  16
# imágenes procesadas:  17
# imágenes procesadas:  18
# imágenes procesadas:  19
# imágenes procesadas:  20
# imágenes procesadas:  21
# imágenes procesadas:  22
# imágenes procesadas:  23
# imágenes procesadas:  24
# imágenes procesadas:  25
# imágenes procesadas:  26
# imágenes procesadas:  27
# imágenes procesadas:  28
# imágenes procesadas:  29
# imágenes procesadas:  30
# imágenes procesadas:  31
# imágenes procesadas:  32
# imágenes procesadas:  33
# imágenes procesadas:  34
# imágenes procesadas:  35
# imágenes procesadas:  36
# imágenes procesadas:  37
# imágenes procesadas:  38
# imágenes procesadas:  39
# imágenes procesadas:  40
# imágenes procesadas:  41
# imágenes procesadas:  42
# imágenes procesadas:  43
# imágenes procesadas:  44
# imágenes procesadas:  45
# imágenes procesadas:  46
# imágenes procesadas:  47
# imágenes procesadas:  48
# imágenes procesadas:  49
# imágenes procesadas:  50
# imágenes procesadas:  51
# imágenes procesadas:  52
# imágenes procesadas:  53
# imágenes procesadas:  54
# imágenes procesadas:  55
# imágenes procesadas:  56
# imágenes procesadas:  57
# imágenes procesadas:  58
# imágenes procesadas:  59
# imágenes procesadas:  60
# imágenes procesadas:  61
# imágenes procesadas:  62
# imágenes procesadas:  63
# imágenes procesadas:  64
# imágenes procesadas:  65
# imágenes procesadas:  66
# imágenes procesadas:  67
# imágenes procesadas:  68
# imágenes procesadas:  69
# imágenes procesadas:  70
# imágenes procesadas:  71
# imágenes procesadas:  72
# imágenes procesadas:  73
# imágenes procesadas:  74
# imágenes procesadas:  75
# imágenes procesadas:  76
# imágenes procesadas:  77
# imágenes procesadas:  78
# imágenes procesadas:  79
# imágenes procesadas:  80
# imágenes procesadas:  81
# imágenes procesadas:  82
# imágenes procesadas:  83
# imágenes procesadas:  84
# imágenes procesadas:  85
# imágenes procesadas:  86
# imágenes procesadas:  87
# imágenes procesadas:  88
# imágenes procesadas:  89
# imágenes procesadas:  90
# imágenes procesadas:  91
# imágenes procesadas:  92
# imágenes procesadas:  93
# imágenes procesadas:  94
# imágenes procesadas:  95
# imágenes procesadas:  96
# imágenes procesadas:  97
# imágenes procesadas:  98
# imágenes procesadas:  99
# imágenes procesadas:  100
# imágenes procesadas:  101
# imágenes procesadas:  102
# imágenes procesadas:  103
# imágenes procesadas:  104
# imágenes procesadas:  105
# imágenes procesadas:  106
# imágenes procesadas:  107
# imágenes procesadas:  108
# imágenes procesadas:  109
# imágenes procesadas:  110
# imágenes procesadas:  111
# imágenes procesadas:  112
# imágenes procesadas:  113
# imágenes procesadas:  114
# imágenes procesadas:  115
# imágenes procesadas:  116
# imágenes procesadas:  117
# imágenes procesadas:  118
# imágenes procesadas:  119
# imágenes procesadas:  120
# imágenes procesadas:  121
# imágenes procesadas:  122
# imágenes procesadas:  123
# imágenes procesadas:  124
# imágenes procesadas:  125
# imágenes procesadas:  126
# imágenes procesadas:  127
# imágenes procesadas:  128
# imágenes procesadas:  129
# imágenes procesadas:  130
# imágenes procesadas:  131
# imágenes procesadas:  132
# imágenes procesadas:  133
# imágenes procesadas:  134
# imágenes procesadas:  135
# imágenes procesadas:  136
# imágenes procesadas:  137
# imágenes procesadas:  138
# imágenes procesadas:  139
# imágenes procesadas:  140
# imágenes procesadas:  141
# imágenes procesadas:  142
# imágenes procesadas:  143
# imágenes procesadas:  144
# imágenes procesadas:  145
# imágenes procesadas:  146
# imágenes procesadas:  147
# imágenes procesadas:  148
# imágenes procesadas:  149
# imágenes procesadas:  150
# imágenes procesadas:  151
# imágenes procesadas:  152
# imágenes procesadas:  153
# imágenes procesadas:  154
# imágenes procesadas:  155
# imágenes procesadas:  156
# imágenes procesadas:  157
# imágenes procesadas:  158
# imágenes procesadas:  159
# imágenes procesadas:  160
# imágenes procesadas:  161
# imágenes procesadas:  162
# imágenes procesadas:  163
# imágenes procesadas:  164
# imágenes procesadas:  165
# imágenes procesadas:  166
# imágenes procesadas:  167
# imágenes procesadas:  168
# imágenes procesadas:  169
# imágenes procesadas:  170
# imágenes procesadas:  171
# imágenes procesadas:  172
# imágenes procesadas:  173
# imágenes procesadas:  174
# imágenes procesadas:  175
# imágenes procesadas:  176
# imágenes procesadas:  177
# imágenes procesadas:  178
# imágenes procesadas:  179
# imágenes procesadas:  180
# imágenes procesadas:  181
# imágenes procesadas:  182
# imágenes procesadas:  183
# imágenes procesadas:  184
# imágenes procesadas:  185
# imágenes procesadas:  186
# imágenes procesadas:  187
# imágenes procesadas:  188
# imágenes procesadas:  189
# imágenes procesadas:  190
# imágenes procesadas:  191
# imágenes procesadas:  192
# imágenes procesadas:  193
# imágenes procesadas:  194
# imágenes procesadas:  195
# imágenes procesadas:  196
# imágenes procesadas:  197
# imágenes procesadas:  198
# imágenes procesadas:  199
# imágenes procesadas:  200
# imágenes procesadas:  201
# imágenes procesadas:  202
# imágenes procesadas:  203
# imágenes procesadas:  204
# imágenes procesadas:  205
# imágenes procesadas:  206
# imágenes procesadas:  207
# imágenes procesadas:  208
# imágenes procesadas:  209
# imágenes procesadas:  210
# imágenes procesadas:  211
# imágenes procesadas:  212
# imágenes procesadas:  213
# imágenes procesadas:  214
# imágenes procesadas:  215
# imágenes procesadas:  216
# imágenes procesadas:  217
# imágenes procesadas:  218
# imágenes procesadas:  219
# imágenes procesadas:  220
# imágenes procesadas:  221
# imágenes procesadas:  222
# imágenes procesadas:  223
# imágenes procesadas:  224
# imágenes procesadas:  225
# imágenes procesadas:  226
# imágenes procesadas:  227
# imágenes procesadas:  228
# imágenes procesadas:  229
# imágenes procesadas:  230
# imágenes procesadas:  231
# imágenes procesadas:  232
# imágenes procesadas:  233
# imágenes procesadas:  234
# imágenes procesadas:  235
# imágenes procesadas:  236
# imágenes procesadas:  237
# imágenes procesadas:  238
# imágenes procesadas:  239
# imágenes procesadas:  240
# imágenes procesadas:  241
# imágenes procesadas:  242
# imágenes procesadas:  243
# imágenes procesadas:  244
# imágenes procesadas:  245
# imágenes procesadas:  246
# imágenes procesadas:  247
# imágenes procesadas:  248
# imágenes procesadas:  249
# imágenes procesadas:  250
# imágenes procesadas:  251
# imágenes procesadas:  252
# imágenes procesadas:  253
# imágenes procesadas:  254
# imágenes procesadas:  255
# imágenes procesadas:  256
# imágenes procesadas:  257
# imágenes procesadas:  258
# imágenes procesadas:  259
# imágenes procesadas:  260
# imágenes procesadas:  261
# imágenes procesadas:  262
# imágenes procesadas:  263
# imágenes procesadas:  264
# imágenes procesadas:  265
# imágenes procesadas:  266
# imágenes procesadas:  267
# imágenes procesadas:  268
# imágenes procesadas:  269
# imágenes procesadas:  270
# imágenes procesadas:  271
# imágenes procesadas:  272
# imágenes procesadas:  273
# imágenes procesadas:  274
# imágenes procesadas:  275
# imágenes procesadas:  276
# imágenes procesadas:  277
# imágenes procesadas:  278
# imágenes procesadas:  279
# imágenes procesadas:  280
# imágenes procesadas:  281
# imágenes procesadas:  282
# imágenes procesadas:  283
# imágenes procesadas:  284
# imágenes procesadas:  285
# imágenes procesadas:  286
# imágenes procesadas:  287
# imágenes procesadas:  288
# imágenes procesadas:  289
# imágenes procesadas:  290
# imágenes procesadas:  291
# imágenes procesadas:  292
# imágenes procesadas:  293
# imágenes procesadas:  294
# imágenes procesadas:  295
# imágenes procesadas:  296
# imágenes procesadas:  297
# imágenes procesadas:  298
# imágenes procesadas:  299
# imágenes procesadas:  300
# imágenes procesadas:  301
# imágenes procesadas:  302
# imágenes procesadas:  303
# imágenes procesadas:  304
# imágenes procesadas:  305
# imágenes procesadas:  306
# imágenes procesadas:  307
# imágenes procesadas:  308
# imágenes procesadas:  309
# imágenes procesadas:  310
# imágenes procesadas:  311
# imágenes procesadas:  312
# imágenes procesadas:  313
# imágenes procesadas:  314
# imágenes procesadas:  315
# imágenes procesadas:  316
# imágenes procesadas:  317
# imágenes procesadas:  318
# imágenes procesadas:  319
# imágenes procesadas:  320
# imágenes procesadas:  321
# imágenes procesadas:  322
# imágenes procesadas:  323
# imágenes procesadas:  324
# imágenes procesadas:  325
# imágenes procesadas:  326
# imágenes procesadas:  327
# imágenes procesadas:  328
# imágenes procesadas:  329
# imágenes procesadas:  330
# imágenes procesadas:  331
# imágenes procesadas:  332
# imágenes procesadas:  333
# imágenes procesadas:  334
# imágenes procesadas:  335
# imágenes procesadas:  336
# imágenes procesadas:  337
# imágenes procesadas:  338
# imágenes procesadas:  339
# imágenes procesadas:  340
# imágenes procesadas:  341
# imágenes procesadas:  342
# imágenes procesadas:  343
# imágenes procesadas:  344
# imágenes procesadas:  345
# imágenes procesadas:  346
# imágenes procesadas:  347
# imágenes procesadas:  348
# imágenes procesadas:  349
# imágenes procesadas:  350
# imágenes procesadas:  351
# imágenes procesadas:  352
# imágenes procesadas:  353
# imágenes procesadas:  354
# imágenes procesadas:  355
# imágenes procesadas:  356
# imágenes procesadas:  357
# imágenes procesadas:  358
# imágenes procesadas:  359
# imágenes procesadas:  360
# imágenes procesadas:  361
# imágenes procesadas:  362
# imágenes procesadas:  363
# imágenes procesadas:  364
# imágenes procesadas:  365
# imágenes procesadas:  366
# imágenes procesadas:  367
# imágenes procesadas:  368
# imágenes procesadas:  369
# imágenes procesadas:  370
# imágenes procesadas:  371
# imágenes procesadas:  372
# imágenes procesadas:  373
# imágenes procesadas:  374
# imágenes procesadas:  375
# imágenes procesadas:  376
# imágenes procesadas:  377
# imágenes procesadas:  378
# imágenes procesadas:  379
# imágenes procesadas:  380
# imágenes procesadas:  381
# imágenes procesadas:  382
# imágenes procesadas:  383
# imágenes procesadas:  384
# imágenes procesadas:  385
# imágenes procesadas:  386
# imágenes procesadas:  387
# imágenes procesadas:  388
# imágenes procesadas:  389
# imágenes procesadas:  390
# imágenes procesadas:  391
# imágenes procesadas:  392
# imágenes procesadas:  393
# imágenes procesadas:  394
# imágenes procesadas:  395
# imágenes procesadas:  396
# imágenes procesadas:  397
# imágenes procesadas:  398
# imágenes procesadas:  399
# imágenes procesadas:  400
# imágenes procesadas:  401
# imágenes procesadas:  402
# imágenes procesadas:  403
# imágenes procesadas:  404
# imágenes procesadas:  405
# imágenes procesadas:  406
# imágenes procesadas:  407
# imágenes procesadas:  408
# imágenes procesadas:  409
# imágenes procesadas:  410
# imágenes procesadas:  411
# imágenes procesadas:  412
# imágenes procesadas:  413
# imágenes procesadas:  414
# imágenes procesadas:  415
# imágenes procesadas:  416
# imágenes procesadas:  417
# imágenes procesadas:  418
# imágenes procesadas:  419
# imágenes procesadas:  420
# imágenes procesadas:  421
# imágenes procesadas:  422
# imágenes procesadas:  423
# imágenes procesadas:  424
# imágenes procesadas:  425
# imágenes procesadas:  426
# imágenes procesadas:  427
# imágenes procesadas:  428
# imágenes procesadas:  429
# imágenes procesadas:  430
# imágenes procesadas:  431
# imágenes procesadas:  432
# imágenes procesadas:  433
# imágenes procesadas:  434
# imágenes procesadas:  435
# imágenes procesadas:  436
# imágenes procesadas:  437
# imágenes procesadas:  438
# imágenes procesadas:  439
# imágenes procesadas:  440
# imágenes procesadas:  441
# imágenes procesadas:  442
# imágenes procesadas:  443
# imágenes procesadas:  444
# imágenes procesadas:  445
# imágenes procesadas:  446
# imágenes procesadas:  447
# imágenes procesadas:  448
# imágenes procesadas:  449
# imágenes procesadas:  450
# imágenes procesadas:  451
# imágenes procesadas:  452
# imágenes procesadas:  453
# imágenes procesadas:  454
# imágenes procesadas:  455
# imágenes procesadas:  456
# imágenes procesadas:  457
# imágenes procesadas:  458
# imágenes procesadas:  459
# imágenes procesadas:  460
# imágenes procesadas:  461
# imágenes procesadas:  462
# imágenes procesadas:  463
# imágenes procesadas:  464
# imágenes procesadas:  465
# imágenes procesadas:  466
# imágenes procesadas:  467
# imágenes procesadas:  468
# imágenes procesadas:  469
# imágenes procesadas:  470
# imágenes procesadas:  471
# imágenes procesadas:  472
# imágenes procesadas:  473
# imágenes procesadas:  474
# imágenes procesadas:  475
# imágenes procesadas:  476
# imágenes procesadas:  477
# imágenes procesadas:  478
# imágenes procesadas:  479
# imágenes procesadas:  480
# imágenes procesadas:  481
# imágenes procesadas:  482
# imágenes procesadas:  483
# imágenes procesadas:  484
# imágenes procesadas:  485
# imágenes procesadas:  486
# imágenes procesadas:  487
# imágenes procesadas:  488
# imágenes procesadas:  489
# imágenes procesadas:  490
# imágenes procesadas:  491
# imágenes procesadas:  492
# imágenes procesadas:  493
# imágenes procesadas:  494
# imágenes procesadas:  495
# imágenes procesadas:  496
# imágenes procesadas:  497
# imágenes procesadas:  498
# imágenes procesadas:  499
# imágenes procesadas:  500
# imágenes procesadas:  501
# imágenes procesadas:  502
# imágenes procesadas:  503
# imágenes procesadas:  504
# imágenes procesadas:  505
# imágenes procesadas:  506
# imágenes procesadas:  507
# imágenes procesadas:  508
# imágenes procesadas:  509
# imágenes procesadas:  510
# imágenes procesadas:  511
# imágenes procesadas:  512
# imágenes procesadas:  513
# imágenes procesadas:  514
# imágenes procesadas:  515
# imágenes procesadas:  516
# imágenes procesadas:  517
# imágenes procesadas:  518
# imágenes procesadas:  519
# imágenes procesadas:  520
# imágenes procesadas:  521
# imágenes procesadas:  522
# imágenes procesadas:  523
# imágenes procesadas:  524
# imágenes procesadas:  525
# imágenes procesadas:  526
# imágenes procesadas:  527
# imágenes procesadas:  528
# imágenes procesadas:  529
# imágenes procesadas:  530
# imágenes procesadas:  531
# imágenes procesadas:  532
# imágenes procesadas:  533
# imágenes procesadas:  534
# imágenes procesadas:  535
# imágenes procesadas:  536
# imágenes procesadas:  537
# imágenes procesadas:  538
# imágenes procesadas:  539
# imágenes procesadas:  540
# imágenes procesadas:  541
# imágenes procesadas:  542
# imágenes procesadas:  543
# imágenes procesadas:  544
# imágenes procesadas:  545
# imágenes procesadas:  546
# imágenes procesadas:  547
# imágenes procesadas:  548
# imágenes procesadas:  549
# imágenes procesadas:  550
# imágenes procesadas:  551
# imágenes procesadas:  552
# imágenes procesadas:  553
# imágenes procesadas:  554
# imágenes procesadas:  555
# imágenes procesadas:  556
# imágenes procesadas:  557
# imágenes procesadas:  558
# imágenes procesadas:  559
# imágenes procesadas:  560
# imágenes procesadas:  561
# imágenes procesadas:  562
# imágenes procesadas:  563
# imágenes procesadas:  564
# imágenes procesadas:  565
# imágenes procesadas:  566
# imágenes procesadas:  567
# imágenes procesadas:  568
# imágenes procesadas:  569
# imágenes procesadas:  570
# imágenes procesadas:  571
# imágenes procesadas:  572
# imágenes procesadas:  573
# imágenes procesadas:  574
# imágenes procesadas:  575
# imágenes procesadas:  576
# imágenes procesadas:  577
# imágenes procesadas:  578
# imágenes procesadas:  579
# imágenes procesadas:  580
# imágenes procesadas:  581
# imágenes procesadas:  582
# imágenes procesadas:  583
# imágenes procesadas:  584
# imágenes procesadas:  585
# imágenes procesadas:  586
# imágenes procesadas:  587
# imágenes procesadas:  588
# imágenes procesadas:  589
# imágenes procesadas:  590
# imágenes procesadas:  591
# imágenes procesadas:  592
# imágenes procesadas:  593
# imágenes procesadas:  594
# imágenes procesadas:  595
# imágenes procesadas:  596
# imágenes procesadas:  597
# imágenes procesadas:  598
# imágenes procesadas:  599
# imágenes procesadas:  600
# imágenes procesadas:  601
# imágenes procesadas:  602
# imágenes procesadas:  603
# imágenes procesadas:  604
# imágenes procesadas:  605
# imágenes procesadas:  606
# imágenes procesadas:  607
# imágenes procesadas:  608
# imágenes procesadas:  609
# imágenes procesadas:  610
# imágenes procesadas:  611
# imágenes procesadas:  612
# imágenes procesadas:  613
# imágenes procesadas:  614
# imágenes procesadas:  615
# imágenes procesadas:  616
# imágenes procesadas:  617
# imágenes procesadas:  618
# imágenes procesadas:  619
# imágenes procesadas:  620
# imágenes procesadas:  621
# imágenes procesadas:  622
# imágenes procesadas:  623
# imágenes procesadas:  624
# imágenes procesadas:  625
# imágenes procesadas:  626
# imágenes procesadas:  627
# imágenes procesadas:  628
# imágenes procesadas:  629
# imágenes procesadas:  630
# imágenes procesadas:  631
# imágenes procesadas:  632
# imágenes procesadas:  633
# imágenes procesadas:  634
# imágenes procesadas:  635
# imágenes procesadas:  636
# imágenes procesadas:  637
# imágenes procesadas:  638
# imágenes procesadas:  639
# imágenes procesadas:  640
# imágenes procesadas:  641
# imágenes procesadas:  642
# imágenes procesadas:  643
# imágenes procesadas:  644
# imágenes procesadas:  645
# imágenes procesadas:  646
# imágenes procesadas:  647
# imágenes procesadas:  648
# imágenes procesadas:  649
# imágenes procesadas:  650
# imágenes procesadas:  651
# imágenes procesadas:  652
# imágenes procesadas:  653
# imágenes procesadas:  654
# imágenes procesadas:  655
# imágenes procesadas:  656
# imágenes procesadas:  657
# imágenes procesadas:  658
# imágenes procesadas:  659
# imágenes procesadas:  660
# imágenes procesadas:  661
# imágenes procesadas:  662
# imágenes procesadas:  663
# imágenes procesadas:  664
# imágenes procesadas:  665
# imágenes procesadas:  666
# imágenes procesadas:  667
# imágenes procesadas:  668
# imágenes procesadas:  669
# imágenes procesadas:  670
# imágenes procesadas:  671
# imágenes procesadas:  672
# imágenes procesadas:  673
# imágenes procesadas:  674
# imágenes procesadas:  675
# imágenes procesadas:  676
# imágenes procesadas:  677
# imágenes procesadas:  678
# imágenes procesadas:  679
# imágenes procesadas:  680
# imágenes procesadas:  681
# imágenes procesadas:  682
# imágenes procesadas:  683
# imágenes procesadas:  684
# imágenes procesadas:  685
# imágenes procesadas:  686
# imágenes procesadas:  687
# imágenes procesadas:  688
# imágenes procesadas:  689
# imágenes procesadas:  690
# imágenes procesadas:  691
# imágenes procesadas:  692
# imágenes procesadas:  693
# imágenes procesadas:  694
# imágenes procesadas:  695
# imágenes procesadas:  696
# imágenes procesadas:  697
# imágenes procesadas:  698
# imágenes procesadas:  699
# imágenes procesadas:  700
# imágenes procesadas:  701
# imágenes procesadas:  702
# imágenes procesadas:  703
# imágenes procesadas:  704
# imágenes procesadas:  705
# imágenes procesadas:  706
# imágenes procesadas:  707
# imágenes procesadas:  708
# imágenes procesadas:  709
# imágenes procesadas:  710
# imágenes procesadas:  711
# imágenes procesadas:  712
# imágenes procesadas:  713
# imágenes procesadas:  714
# imágenes procesadas:  715
# imágenes procesadas:  716
# imágenes procesadas:  717
# imágenes procesadas:  718
# imágenes procesadas:  719
# imágenes procesadas:  720
# imágenes procesadas:  721
# imágenes procesadas:  722
# imágenes procesadas:  723
# imágenes procesadas:  724
# imágenes procesadas:  725
# imágenes procesadas:  726
# imágenes procesadas:  727
# imágenes procesadas:  728
# imágenes procesadas:  729
# imágenes procesadas:  730
# imágenes procesadas:  731
# imágenes procesadas:  732
# imágenes procesadas:  733
# imágenes procesadas:  734
# imágenes procesadas:  735
# imágenes procesadas:  736
# imágenes procesadas:  737
# imágenes procesadas:  738
# imágenes procesadas:  739
# imágenes procesadas:  740
# imágenes procesadas:  741
# imágenes procesadas:  742
# imágenes procesadas:  743
# imágenes procesadas:  744
# imágenes procesadas:  745
# imágenes procesadas:  746
# imágenes procesadas:  747
# imágenes procesadas:  748
# imágenes procesadas:  749
# imágenes procesadas:  750
# imágenes procesadas:  751
# imágenes procesadas:  752
# imágenes procesadas:  753
# imágenes procesadas:  754
# imágenes procesadas:  755
# imágenes procesadas:  756
# imágenes procesadas:  757
# imágenes procesadas:  758
# imágenes procesadas:  759
# imágenes procesadas:  760
# imágenes procesadas:  761
# imágenes procesadas:  762
# imágenes procesadas:  763
# imágenes procesadas:  764
# imágenes procesadas:  765
# imágenes procesadas:  766
# imágenes procesadas:  767
# imágenes procesadas:  768
# imágenes procesadas:  769
# imágenes procesadas:  770
# imágenes procesadas:  771
# imágenes procesadas:  772
# imágenes procesadas:  773
# imágenes procesadas:  774
# imágenes procesadas:  775
# imágenes procesadas:  776
# imágenes procesadas:  777
# imágenes procesadas:  778
# imágenes procesadas:  779
# imágenes procesadas:  780
# imágenes procesadas:  781
# imágenes procesadas:  782
# imágenes procesadas:  783
# imágenes procesadas:  784
# imágenes procesadas:  785
# imágenes procesadas:  786
# imágenes procesadas:  787
# imágenes procesadas:  788
# imágenes procesadas:  789
# imágenes procesadas:  790
# imágenes procesadas:  791
# imágenes procesadas:  792
# imágenes procesadas:  793
# imágenes procesadas:  794
# imágenes procesadas:  795
# imágenes procesadas:  796
# imágenes procesadas:  797
# imágenes procesadas:  798
# imágenes procesadas:  799
# imágenes procesadas:  800
# imágenes procesadas:  801
# imágenes procesadas:  802
# imágenes procesadas:  803
# imágenes procesadas:  804
# imágenes procesadas:  805
# imágenes procesadas:  806
# imágenes procesadas:  807
# imágenes procesadas:  808
# imágenes procesadas:  809
# imágenes procesadas:  810
# imágenes procesadas:  811
# imágenes procesadas:  812
# imágenes procesadas:  813
# imágenes procesadas:  814
# imágenes procesadas:  815
# imágenes procesadas:  816
# imágenes procesadas:  817
# imágenes procesadas:  818
# imágenes procesadas:  819
# imágenes procesadas:  820
# imágenes procesadas:  821
# imágenes procesadas:  822
# imágenes procesadas:  823
# imágenes procesadas:  824
# imágenes procesadas:  825
# imágenes procesadas:  826
# imágenes procesadas:  827
# imágenes procesadas:  828
# imágenes procesadas:  829
# imágenes procesadas:  830
# imágenes procesadas:  831
# imágenes procesadas:  832
# imágenes procesadas:  833
# imágenes procesadas:  834
# imágenes procesadas:  835
# imágenes procesadas:  836
# imágenes procesadas:  837
# imágenes procesadas:  838
# imágenes procesadas:  839
# imágenes procesadas:  840
# imágenes procesadas:  841
# imágenes procesadas:  842
# imágenes procesadas:  843
# imágenes procesadas:  844
# imágenes procesadas:  845
# imágenes procesadas:  846
# imágenes procesadas:  847
# imágenes procesadas:  848
# imágenes procesadas:  849
# imágenes procesadas:  850
# imágenes procesadas:  851
# imágenes procesadas:  852
# imágenes procesadas:  853
# imágenes procesadas:  854
# imágenes procesadas:  855
# imágenes procesadas:  856
# imágenes procesadas:  857
# imágenes procesadas:  858
# imágenes procesadas:  859
# imágenes procesadas:  860
# imágenes procesadas:  861
# imágenes procesadas:  862
# imágenes procesadas:  863
# imágenes procesadas:  864
# imágenes procesadas:  865
# imágenes procesadas:  866
# imágenes procesadas:  867
# imágenes procesadas:  868
# imágenes procesadas:  869
# imágenes procesadas:  870
# imágenes procesadas:  871
# imágenes procesadas:  872
# imágenes procesadas:  873
# imágenes procesadas:  874
# imágenes procesadas:  875
# imágenes procesadas:  876
# imágenes procesadas:  877
# imágenes procesadas:  878
# imágenes procesadas:  879
# imágenes procesadas:  880
# imágenes procesadas:  881
# imágenes procesadas:  882
# imágenes procesadas:  883
# imágenes procesadas:  884
# imágenes procesadas:  885
# imágenes procesadas:  886
# imágenes procesadas:  887
# imágenes procesadas:  888
# imágenes procesadas:  889
# imágenes procesadas:  890
# imágenes procesadas:  891
# imágenes procesadas:  892
# imágenes procesadas:  893
# imágenes procesadas:  894
# imágenes procesadas:  895
# imágenes procesadas:  896
# imágenes procesadas:  897
# imágenes procesadas:  898
# imágenes procesadas:  899
# imágenes procesadas:  900
# imágenes procesadas:  901
# imágenes procesadas:  902
# imágenes procesadas:  903
# imágenes procesadas:  904
# imágenes procesadas:  905
# imágenes procesadas:  906
# imágenes procesadas:  907
# imágenes procesadas:  908
# imágenes procesadas:  909
# imágenes procesadas:  910
# imágenes procesadas:  911
# imágenes procesadas:  912
# imágenes procesadas:  913
# imágenes procesadas:  914
# imágenes procesadas:  915
# imágenes procesadas:  916
# imágenes procesadas:  917
# imágenes procesadas:  918
# imágenes procesadas:  919
# imágenes procesadas:  920
# imágenes procesadas:  921
# imágenes procesadas:  922
# imágenes procesadas:  923
# imágenes procesadas:  924
# imágenes procesadas:  925
# imágenes procesadas:  926
# imágenes procesadas:  927
# imágenes procesadas:  928
# imágenes procesadas:  929
# imágenes procesadas:  930
# imágenes procesadas:  931
# imágenes procesadas:  932
# imágenes procesadas:  933
# imágenes procesadas:  934
# imágenes procesadas:  935
# imágenes procesadas:  936
# imágenes procesadas:  937
# imágenes procesadas:  938
# imágenes procesadas:  939
# imágenes procesadas:  940
# imágenes procesadas:  941
# imágenes procesadas:  942
# imágenes procesadas:  943
# imágenes procesadas:  944
# imágenes procesadas:  945
# imágenes procesadas:  946
# imágenes procesadas:  947
# imágenes procesadas:  948
# imágenes procesadas:  949
# imágenes procesadas:  950
# imágenes procesadas:  951
# imágenes procesadas:  952
# imágenes procesadas:  953
# imágenes procesadas:  954
# imágenes procesadas:  955
# imágenes procesadas:  956
# imágenes procesadas:  957
# imágenes procesadas:  958
# imágenes procesadas:  959
# imágenes procesadas:  960
# imágenes procesadas:  961
# imágenes procesadas:  962
# imágenes procesadas:  963
# imágenes procesadas:  964
# imágenes procesadas:  965
# imágenes procesadas:  966
# imágenes procesadas:  967
# imágenes procesadas:  968
# imágenes procesadas:  969
# imágenes procesadas:  970
# imágenes procesadas:  971
# imágenes procesadas:  972
# imágenes procesadas:  973
# imágenes procesadas:  974
# imágenes procesadas:  975
# imágenes procesadas:  976
# imágenes procesadas:  977
# imágenes procesadas:  978
# imágenes procesadas:  979
# imágenes procesadas:  980
# imágenes procesadas:  981
# imágenes procesadas:  982
# imágenes procesadas:  983
# imágenes procesadas:  984
# imágenes procesadas:  985
# imágenes procesadas:  986
# imágenes procesadas:  987
# imágenes procesadas:  988
# imágenes procesadas:  989
# imágenes procesadas:  990
# imágenes procesadas:  991
# imágenes procesadas:  992
# imágenes procesadas:  993
# imágenes procesadas:  994
# imágenes procesadas:  995
# imágenes procesadas:  996
# imágenes procesadas:  997
# imágenes procesadas:  998
# imágenes procesadas:  999
# imágenes procesadas:  1000
# imágenes procesadas:  1001
# imágenes procesadas:  1002
# imágenes procesadas:  1003
# imágenes procesadas:  1004
# imágenes procesadas:  1005
# imágenes procesadas:  1006
# imágenes procesadas:  1007
# imágenes procesadas:  1008
# imágenes procesadas:  1009
# imágenes procesadas:  1010
# imágenes procesadas:  1011
# imágenes procesadas:  1012
# imágenes procesadas:  1013
# imágenes procesadas:  1014
# imágenes procesadas:  1015
# imágenes procesadas:  1016
# imágenes procesadas:  1017
# imágenes procesadas:  1018
# imágenes procesadas:  1019
# imágenes procesadas:  1020
# imágenes procesadas:  1021
# imágenes procesadas:  1022
# imágenes procesadas:  1023
# imágenes procesadas:  1024
# imágenes procesadas:  1025
# imágenes procesadas:  1026
# imágenes procesadas:  1027
# imágenes procesadas:  1028
# imágenes procesadas:  1029
# imágenes procesadas:  1030
# imágenes procesadas:  1031
# imágenes procesadas:  1032
# imágenes procesadas:  1033
# imágenes procesadas:  1034
# imágenes procesadas:  1035
# imágenes procesadas:  1036
# imágenes procesadas:  1037
# imágenes procesadas:  1038
# imágenes procesadas:  1039
# imágenes procesadas:  1040
# imágenes procesadas:  1041
# imágenes procesadas:  1042
# imágenes procesadas:  1043
# imágenes procesadas:  1044
# imágenes procesadas:  1045
# imágenes procesadas:  1046
# imágenes procesadas:  1047
# imágenes procesadas:  1048
# imágenes procesadas:  1049
# imágenes procesadas:  1050
# imágenes procesadas:  1051
# imágenes procesadas:  1052
# imágenes procesadas:  1053
# imágenes procesadas:  1054
# imágenes procesadas:  1055
# imágenes procesadas:  1056
# imágenes procesadas:  1057
# imágenes procesadas:  1058
# imágenes procesadas:  1059
# imágenes procesadas:  1060
# imágenes procesadas:  1061
# imágenes procesadas:  1062
# imágenes procesadas:  1063
# imágenes procesadas:  1064
# imágenes procesadas:  1065
# imágenes procesadas:  1066
# imágenes procesadas:  1067
# imágenes procesadas:  1068
# imágenes procesadas:  1069
# imágenes procesadas:  1070
# imágenes procesadas:  1071
# imágenes procesadas:  1072
# imágenes procesadas:  1073
# imágenes procesadas:  1074
# imágenes procesadas:  1075
# imágenes procesadas:  1076
# imágenes procesadas:  1077
# imágenes procesadas:  1078
# imágenes procesadas:  1079
# imágenes procesadas:  1080
# imágenes procesadas:  1081
# imágenes procesadas:  1082
# imágenes procesadas:  1083
# imágenes procesadas:  1084
# imágenes procesadas:  1085
# imágenes procesadas:  1086
# imágenes procesadas:  1087
# imágenes procesadas:  1088
# imágenes procesadas:  1089
# imágenes procesadas:  1090
# imágenes procesadas:  1091
# imágenes procesadas:  1092
# imágenes procesadas:  1093
# imágenes procesadas:  1094
# imágenes procesadas:  1095
# imágenes procesadas:  1096
# imágenes procesadas:  1097
# imágenes procesadas:  1098
# imágenes procesadas:  1099
# imágenes procesadas:  1100
# imágenes procesadas:  1101
# imágenes procesadas:  1102
# imágenes procesadas:  1103
# imágenes procesadas:  1104
# imágenes procesadas:  1105
# imágenes procesadas:  1106
# imágenes procesadas:  1107
# imágenes procesadas:  1108
# imágenes procesadas:  1109
# imágenes procesadas:  1110
# imágenes procesadas:  1111
# imágenes procesadas:  1112
# imágenes procesadas:  1113
# imágenes procesadas:  1114
# imágenes procesadas:  1115
# imágenes procesadas:  1116
# imágenes procesadas:  1117
# imágenes procesadas:  1118
# imágenes procesadas:  1119
# imágenes procesadas:  1120
# imágenes procesadas:  1121
# imágenes procesadas:  1122
# imágenes procesadas:  1123
# imágenes procesadas:  1124
# imágenes procesadas:  1125
# imágenes procesadas:  1126
# imágenes procesadas:  1127
# imágenes procesadas:  1128
# imágenes procesadas:  1129
# imágenes procesadas:  1130
# imágenes procesadas:  1131
# imágenes procesadas:  1132
# imágenes procesadas:  1133
# imágenes procesadas:  1134
# imágenes procesadas:  1135
# imágenes procesadas:  1136
# imágenes procesadas:  1137
# imágenes procesadas:  1138
# imágenes procesadas:  1139
# imágenes procesadas:  1140
# imágenes procesadas:  1141
# imágenes procesadas:  1142
# imágenes procesadas:  1143
# imágenes procesadas:  1144
# imágenes procesadas:  1145
# imágenes procesadas:  1146
# imágenes procesadas:  1147
# imágenes procesadas:  1148
# imágenes procesadas:  1149
# imágenes procesadas:  1150
# imágenes procesadas:  1151
# imágenes procesadas:  1152
# imágenes procesadas:  1153
# imágenes procesadas:  1154
# imágenes procesadas:  1155
# imágenes procesadas:  1156
# imágenes procesadas:  1157
# imágenes procesadas:  1158
# imágenes procesadas:  1159
# imágenes procesadas:  1160
# imágenes procesadas:  1161
# imágenes procesadas:  1162
# imágenes procesadas:  1163
# imágenes procesadas:  1164
# imágenes procesadas:  1165
# imágenes procesadas:  1166
# imágenes procesadas:  1167
# imágenes procesadas:  1168
# imágenes procesadas:  1169
# imágenes procesadas:  1170
# imágenes procesadas:  1171
# imágenes procesadas:  1172
# imágenes procesadas:  1173
# imágenes procesadas:  1174
# imágenes procesadas:  1175
# imágenes procesadas:  1176
# imágenes procesadas:  1177
# imágenes procesadas:  1178
# imágenes procesadas:  1179
# imágenes procesadas:  1180
# imágenes procesadas:  1181
# imágenes procesadas:  1182
# imágenes procesadas:  1183
# imágenes procesadas:  1184
# imágenes procesadas:  1185
# imágenes procesadas:  1186
# imágenes procesadas:  1187
# imágenes procesadas:  1188
# imágenes procesadas:  1189
# imágenes procesadas:  1190
# imágenes procesadas:  1191
# imágenes procesadas:  1192
# imágenes procesadas:  1193
# imágenes procesadas:  1194
# imágenes procesadas:  1195
# imágenes procesadas:  1196
# imágenes procesadas:  1197
# imágenes procesadas:  1198
# imágenes procesadas:  1199
# imágenes procesadas:  1200
# imágenes procesadas:  1201
# imágenes procesadas:  1202
# imágenes procesadas:  1203
# imágenes procesadas:  1204
# imágenes procesadas:  1205
# imágenes procesadas:  1206
# imágenes procesadas:  1207
# imágenes procesadas:  1208
# imágenes procesadas:  1209
# imágenes procesadas:  1210
# imágenes procesadas:  1211
# imágenes procesadas:  1212
# imágenes procesadas:  1213
# imágenes procesadas:  1214
# imágenes procesadas:  1215
# imágenes procesadas:  1216
# imágenes procesadas:  1217
# imágenes procesadas:  1218
# imágenes procesadas:  1219
# imágenes procesadas:  1220
# imágenes procesadas:  1221
# imágenes procesadas:  1222
# imágenes procesadas:  1223
# imágenes procesadas:  1224
# imágenes procesadas:  1225
# imágenes procesadas:  1226
# imágenes procesadas:  1227
# imágenes procesadas:  1228
# imágenes procesadas:  1229
# imágenes procesadas:  1230
# imágenes procesadas:  1231
# imágenes procesadas:  1232
# imágenes procesadas:  1233
# imágenes procesadas:  1234
# imágenes procesadas:  1235
# imágenes procesadas:  1236
# imágenes procesadas:  1237
# imágenes procesadas:  1238
# imágenes procesadas:  1239
# imágenes procesadas:  1240
# imágenes procesadas:  1241
# imágenes procesadas:  1242
# imágenes procesadas:  1243
# imágenes procesadas:  1244
# imágenes procesadas:  1245
# imágenes procesadas:  1246
# imágenes procesadas:  1247
# imágenes procesadas:  1248
# imágenes procesadas:  1249
# imágenes procesadas:  1250
# imágenes procesadas:  1251
# imágenes procesadas:  1252
# imágenes procesadas:  1253
# imágenes procesadas:  1254
# imágenes procesadas:  1255
# imágenes procesadas:  1256
# imágenes procesadas:  1257
# imágenes procesadas:  1258
# imágenes procesadas:  1259
# imágenes procesadas:  1260
# imágenes procesadas:  1261
# imágenes procesadas:  1262
# imágenes procesadas:  1263
# imágenes procesadas:  1264
# imágenes procesadas:  1265
# imágenes procesadas:  1266
# imágenes procesadas:  1267
# imágenes procesadas:  1268
# imágenes procesadas:  1269
# imágenes procesadas:  1270
# imágenes procesadas:  1271
# imágenes procesadas:  1272
# imágenes procesadas:  1273
# imágenes procesadas:  1274
# imágenes procesadas:  1275
# imágenes procesadas:  1276
# imágenes procesadas:  1277
# imágenes procesadas:  1278
# imágenes procesadas:  1279
# imágenes procesadas:  1280
# imágenes procesadas:  1281
# imágenes procesadas:  1282
# imágenes procesadas:  1283
# imágenes procesadas:  1284
# imágenes procesadas:  1285
# imágenes procesadas:  1286
# imágenes procesadas:  1287
# imágenes procesadas:  1288
# imágenes procesadas:  1289
# imágenes procesadas:  1290
# imágenes procesadas:  1291
# imágenes procesadas:  1292
# imágenes procesadas:  1293
# imágenes procesadas:  1294
# imágenes procesadas:  1295
# imágenes procesadas:  1296
# imágenes procesadas:  1297
# imágenes procesadas:  1298
# imágenes procesadas:  1299
# imágenes procesadas:  1300
# imágenes procesadas:  1301
# imágenes procesadas:  1302
# imágenes procesadas:  1303
# imágenes procesadas:  1304
# imágenes procesadas:  1305
# imágenes procesadas:  1306
# imágenes procesadas:  1307
# imágenes procesadas:  1308
# imágenes procesadas:  1309
# imágenes procesadas:  1310
# imágenes procesadas:  1311
# imágenes procesadas:  1312
# imágenes procesadas:  1313
# imágenes procesadas:  1314
# imágenes procesadas:  1315
# imágenes procesadas:  1316
# imágenes procesadas:  1317
# imágenes procesadas:  1318
# imágenes procesadas:  1319
# imágenes procesadas:  1320
# imágenes procesadas:  1321
# imágenes procesadas:  1322
# imágenes procesadas:  1323
# imágenes procesadas:  1324
# imágenes procesadas:  1325
# imágenes procesadas:  1326
# imágenes procesadas:  1327
# imágenes procesadas:  1328
# imágenes procesadas:  1329
# imágenes procesadas:  1330
# imágenes procesadas:  1331
# imágenes procesadas:  1332
# imágenes procesadas:  1333
# imágenes procesadas:  1334
# imágenes procesadas:  1335
# imágenes procesadas:  1336
# imágenes procesadas:  1337
# imágenes procesadas:  1338
# imágenes procesadas:  1339
# imágenes procesadas:  1340
# imágenes procesadas:  1341
# imágenes procesadas:  1342
# imágenes procesadas:  1343
# imágenes procesadas:  1344
# imágenes procesadas:  1345
# imágenes procesadas:  1346
# imágenes procesadas:  1347
# imágenes procesadas:  1348
# imágenes procesadas:  1349
# imágenes procesadas:  1350
# imágenes procesadas:  1351
# imágenes procesadas:  1352
# imágenes procesadas:  1353
# imágenes procesadas:  1354
# imágenes procesadas:  1355
# imágenes procesadas:  1356
# imágenes procesadas:  1357
# imágenes procesadas:  1358
# imágenes procesadas:  1359
# imágenes procesadas:  1360
# imágenes procesadas:  1361
# imágenes procesadas:  1362
# imágenes procesadas:  1363
# imágenes procesadas:  1364
# imágenes procesadas:  1365
# imágenes procesadas:  1366
# imágenes procesadas:  1367
# imágenes procesadas:  1368
# imágenes procesadas:  1369
# imágenes procesadas:  1370
# imágenes procesadas:  1371
# imágenes procesadas:  1372
# imágenes procesadas:  1373
# imágenes procesadas:  1374
# imágenes procesadas:  1375
# imágenes procesadas:  1376
# imágenes procesadas:  1377
# imágenes procesadas:  1378
# imágenes procesadas:  1379
# imágenes procesadas:  1380
# imágenes procesadas:  1381
# imágenes procesadas:  1382
# imágenes procesadas:  1383
# imágenes procesadas:  1384
# imágenes procesadas:  1385
# imágenes procesadas:  1386
# imágenes procesadas:  1387
# imágenes procesadas:  1388
# imágenes procesadas:  1389
# imágenes procesadas:  1390
# imágenes procesadas:  1391
# imágenes procesadas:  1392
# imágenes procesadas:  1393
# imágenes procesadas:  1394
# imágenes procesadas:  1395
# imágenes procesadas:  1396
# imágenes procesadas:  1397
# imágenes procesadas:  1398
# imágenes procesadas:  1399
# imágenes procesadas:  1400
# imágenes procesadas:  1401
# imágenes procesadas:  1402
# imágenes procesadas:  1403
# imágenes procesadas:  1404
# imágenes procesadas:  1405
# imágenes procesadas:  1406
# imágenes procesadas:  1407
# imágenes procesadas:  1408
# imágenes procesadas:  1409
# imágenes procesadas:  1410
# imágenes procesadas:  1411
# imágenes procesadas:  1412
# imágenes procesadas:  1413
# imágenes procesadas:  1414
# imágenes procesadas:  1415
# imágenes procesadas:  1416
# imágenes procesadas:  1417
# imágenes procesadas:  1418
# imágenes procesadas:  1419
# imágenes procesadas:  1420
# imágenes procesadas:  1421
# imágenes procesadas:  1422
# imágenes procesadas:  1423
# imágenes procesadas:  1424
# imágenes procesadas:  1425
# imágenes procesadas:  1426
# imágenes procesadas:  1427
# imágenes procesadas:  1428
# imágenes procesadas:  1429
# imágenes procesadas:  1430
# imágenes procesadas:  1431
# imágenes procesadas:  1432
# imágenes procesadas:  1433
# imágenes procesadas:  1434
# imágenes procesadas:  1435
# imágenes procesadas:  1436
# imágenes procesadas:  1437
# imágenes procesadas:  1438
# imágenes procesadas:  1439
# imágenes procesadas:  1440
# imágenes procesadas:  1441
# imágenes procesadas:  1442
# imágenes procesadas:  1443
# imágenes procesadas:  1444
# imágenes procesadas:  1445
# imágenes procesadas:  1446
# imágenes procesadas:  1447
# imágenes procesadas:  1448
# imágenes procesadas:  1449
# imágenes procesadas:  1450
# imágenes procesadas:  1451
# imágenes procesadas:  1452
# imágenes procesadas:  1453
# imágenes procesadas:  1454
# imágenes procesadas:  1455
# imágenes procesadas:  1456
# imágenes procesadas:  1457
# imágenes procesadas:  1458
# imágenes procesadas:  1459
# imágenes procesadas:  1460
# imágenes procesadas:  1461
# imágenes procesadas:  1462
# imágenes procesadas:  1463
# imágenes procesadas:  1464
# imágenes procesadas:  1465
# imágenes procesadas:  1466
# imágenes procesadas:  1467
# imágenes procesadas:  1468
# imágenes procesadas:  1469
# imágenes procesadas:  1470
# imágenes procesadas:  1471
# imágenes procesadas:  1472
# imágenes procesadas:  1473
# imágenes procesadas:  1474
# imágenes procesadas:  1475
# imágenes procesadas:  1476
# imágenes procesadas:  1477
# imágenes procesadas:  1478
# imágenes procesadas:  1479
# imágenes procesadas:  1480
# imágenes procesadas:  1481
# imágenes procesadas:  1482
# imágenes procesadas:  1483
# imágenes procesadas:  1484
# imágenes procesadas:  1485
# imágenes procesadas:  1486
# imágenes procesadas:  1487
# imágenes procesadas:  1488
# imágenes procesadas:  1489
# imágenes procesadas:  1490
# imágenes procesadas:  1491
# imágenes procesadas:  1492
# imágenes procesadas:  1493
# imágenes procesadas:  1494
# imágenes procesadas:  1495
# imágenes procesadas:  1496
# imágenes procesadas:  1497
# imágenes procesadas:  1498
# imágenes procesadas:  1499
# imágenes procesadas:  1500
# imágenes procesadas:  1501
# imágenes procesadas:  1502
# imágenes procesadas:  1503
# imágenes procesadas:  1504
# imágenes procesadas:  1505
# imágenes procesadas:  1506
# imágenes procesadas:  1507
# imágenes procesadas:  1508
# imágenes procesadas:  1509
# imágenes procesadas:  1510
# imágenes procesadas:  1511
# imágenes procesadas:  1512
# imágenes procesadas:  1513
# imágenes procesadas:  1514
# imágenes procesadas:  1515
# imágenes procesadas:  1516
# imágenes procesadas:  1517
# imágenes procesadas:  1518
# imágenes procesadas:  1519
# imágenes procesadas:  1520
# imágenes procesadas:  1521
# imágenes procesadas:  1522
# imágenes procesadas:  1523
# imágenes procesadas:  1524
# imágenes procesadas:  1525
# imágenes procesadas:  1526
# imágenes procesadas:  1527
# imágenes procesadas:  1528
# imágenes procesadas:  1529
# imágenes procesadas:  1530
# imágenes procesadas:  1531
# imágenes procesadas:  1532
# imágenes procesadas:  1533
# imágenes procesadas:  1534
# imágenes procesadas:  1535
# imágenes procesadas:  1536
# imágenes procesadas:  1537
# imágenes procesadas:  1538
# imágenes procesadas:  1539
# imágenes procesadas:  1540
# imágenes procesadas:  1541
# imágenes procesadas:  1542
# imágenes procesadas:  1543
# imágenes procesadas:  1544
# imágenes procesadas:  1545
# imágenes procesadas:  1546
# imágenes procesadas:  1547
# imágenes procesadas:  1548
# imágenes procesadas:  1549
# imágenes procesadas:  1550
# imágenes procesadas:  1551
# imágenes procesadas:  1552
# imágenes procesadas:  1553
# imágenes procesadas:  1554
# imágenes procesadas:  1555
# imágenes procesadas:  1556
# imágenes procesadas:  1557
# imágenes procesadas:  1558
# imágenes procesadas:  1559
# imágenes procesadas:  1560
# imágenes procesadas:  1561
# imágenes procesadas:  1562
# imágenes procesadas:  1563
# imágenes procesadas:  1564
# imágenes procesadas:  1565
# imágenes procesadas:  1566
# imágenes procesadas:  1567
# imágenes procesadas:  1568
# imágenes procesadas:  1569
# imágenes procesadas:  1570
# imágenes procesadas:  1571
# imágenes procesadas:  1572
# imágenes procesadas:  1573
# imágenes procesadas:  1574
# imágenes procesadas:  1575
# imágenes procesadas:  1576
# imágenes procesadas:  1577
# imágenes procesadas:  1578
# imágenes procesadas:  1579
# imágenes procesadas:  1580
# imágenes procesadas:  1581
# imágenes procesadas:  1582
# imágenes procesadas:  1583
# imágenes procesadas:  1584
# imágenes procesadas:  1585
# imágenes procesadas:  1586
# imágenes procesadas:  1587
# imágenes procesadas:  1588
# imágenes procesadas:  1589
# imágenes procesadas:  1590
# imágenes procesadas:  1591
# imágenes procesadas:  1592
# imágenes procesadas:  1593
# imágenes procesadas:  1594
# imágenes procesadas:  1595
# imágenes procesadas:  1596
# imágenes procesadas:  1597
# imágenes procesadas:  1598
# imágenes procesadas:  1599
# imágenes procesadas:  1600
# imágenes procesadas:  1601
# imágenes procesadas:  1602
# imágenes procesadas:  1603
# imágenes procesadas:  1604
# imágenes procesadas:  1605
# imágenes procesadas:  1606
# imágenes procesadas:  1607
# imágenes procesadas:  1608
# imágenes procesadas:  1609
# imágenes procesadas:  1610
# imágenes procesadas:  1611
# imágenes procesadas:  1612
# imágenes procesadas:  1613
# imágenes procesadas:  1614
# imágenes procesadas:  1615
# imágenes procesadas:  1616
# imágenes procesadas:  1617
# imágenes procesadas:  1618
# imágenes procesadas:  1619
# imágenes procesadas:  1620
# imágenes procesadas:  1621
# imágenes procesadas:  1622
# imágenes procesadas:  1623
# imágenes procesadas:  1624
# imágenes procesadas:  1625
# imágenes procesadas:  1626
# imágenes procesadas:  1627
# imágenes procesadas:  1628
# imágenes procesadas:  1629
# imágenes procesadas:  1630
# imágenes procesadas:  1631
# imágenes procesadas:  1632
# imágenes procesadas:  1633
# imágenes procesadas:  1634
# imágenes procesadas:  1635
# imágenes procesadas:  1636
# imágenes procesadas:  1637
# imágenes procesadas:  1638
# imágenes procesadas:  1639
# imágenes procesadas:  1640
# imágenes procesadas:  1641
# imágenes procesadas:  1642
# imágenes procesadas:  1643
# imágenes procesadas:  1644
# imágenes procesadas:  1645
# imágenes procesadas:  1646
# imágenes procesadas:  1647
# imágenes procesadas:  1648
# imágenes procesadas:  1649
# imágenes procesadas:  1650
# imágenes procesadas:  1651
# imágenes procesadas:  1652
# imágenes procesadas:  1653
# imágenes procesadas:  1654
# imágenes procesadas:  1655
# imágenes procesadas:  1656
# imágenes procesadas:  1657
# imágenes procesadas:  1658
# imágenes procesadas:  1659
# imágenes procesadas:  1660
# imágenes procesadas:  1661
# imágenes procesadas:  1662
# imágenes procesadas:  1663
# imágenes procesadas:  1664
# imágenes procesadas:  1665
# imágenes procesadas:  1666
# imágenes procesadas:  1667
# imágenes procesadas:  1668
# imágenes procesadas:  1669
# imágenes procesadas:  1670
# imágenes procesadas:  1671
# imágenes procesadas:  1672
# imágenes procesadas:  1673
# imágenes procesadas:  1674
# imágenes procesadas:  1675
# imágenes procesadas:  1676
# imágenes procesadas:  1677
# imágenes procesadas:  1678
# imágenes procesadas:  1679
# imágenes procesadas:  1680
# imágenes procesadas:  1681
# imágenes procesadas:  1682
# imágenes procesadas:  1683
# imágenes procesadas:  1684
# imágenes procesadas:  1685
# imágenes procesadas:  1686
# imágenes procesadas:  1687
# imágenes procesadas:  1688
# imágenes procesadas:  1689
# imágenes procesadas:  1690
# imágenes procesadas:  1691
# imágenes procesadas:  1692
# imágenes procesadas:  1693
# imágenes procesadas:  1694
# imágenes procesadas:  1695
# imágenes procesadas:  1696
# imágenes procesadas:  1697
# imágenes procesadas:  1698
# imágenes procesadas:  1699
# imágenes procesadas:  1700
# imágenes procesadas:  1701
# imágenes procesadas:  1702
# imágenes procesadas:  1703
# imágenes procesadas:  1704
# imágenes procesadas:  1705
# imágenes procesadas:  1706
# imágenes procesadas:  1707
# imágenes procesadas:  1708
# imágenes procesadas:  1709
# imágenes procesadas:  1710
# imágenes procesadas:  1711
# imágenes procesadas:  1712
# imágenes procesadas:  1713
# imágenes procesadas:  1714
# imágenes procesadas:  1715
# imágenes procesadas:  1716
# imágenes procesadas:  1717
# imágenes procesadas:  1718
# imágenes procesadas:  1719
# imágenes procesadas:  1720
# imágenes procesadas:  1721
# imágenes procesadas:  1722
# imágenes procesadas:  1723
# imágenes procesadas:  1724
# imágenes procesadas:  1725
# imágenes procesadas:  1726
# imágenes procesadas:  1727
# imágenes procesadas:  1728
# imágenes procesadas:  1729
# imágenes procesadas:  1730
# imágenes procesadas:  1731
# imágenes procesadas:  1732
# imágenes procesadas:  1733
# imágenes procesadas:  1734
# imágenes procesadas:  1735
# imágenes procesadas:  1736
# imágenes procesadas:  1737
# imágenes procesadas:  1738
# imágenes procesadas:  1739
# imágenes procesadas:  1740
# imágenes procesadas:  1741
# imágenes procesadas:  1742
# imágenes procesadas:  1743
# imágenes procesadas:  1744
# imágenes procesadas:  1745
# imágenes procesadas:  1746
# imágenes procesadas:  1747
# imágenes procesadas:  1748
# imágenes procesadas:  1749
# imágenes procesadas:  1750
# imágenes procesadas:  1751
# imágenes procesadas:  1752
# imágenes procesadas:  1753
# imágenes procesadas:  1754
# imágenes procesadas:  1755
# imágenes procesadas:  1756
# imágenes procesadas:  1757
# imágenes procesadas:  1758
# imágenes procesadas:  1759
# imágenes procesadas:  1760
# imágenes procesadas:  1761
# imágenes procesadas:  1762
# imágenes procesadas:  1763
# imágenes procesadas:  1764
# imágenes procesadas:  1765
# imágenes procesadas:  1766
# imágenes procesadas:  1767
# imágenes procesadas:  1768
# imágenes procesadas:  1769
# imágenes procesadas:  1770
# imágenes procesadas:  1771
# imágenes procesadas:  1772
# imágenes procesadas:  1773
# imágenes procesadas:  1774
# imágenes procesadas:  1775
# imágenes procesadas:  1776
# imágenes procesadas:  1777
# imágenes procesadas:  1778
# imágenes procesadas:  1779
# imágenes procesadas:  1780
# imágenes procesadas:  1781
# imágenes procesadas:  1782
# imágenes procesadas:  1783
# imágenes procesadas:  1784
# imágenes procesadas:  1785
# imágenes procesadas:  1786
# imágenes procesadas:  1787
# imágenes procesadas:  1788
# imágenes procesadas:  1789
# imágenes procesadas:  1790
# imágenes procesadas:  1791
# imágenes procesadas:  1792
# imágenes procesadas:  1793
# imágenes procesadas:  1794
# imágenes procesadas:  1795
# imágenes procesadas:  1796
# imágenes procesadas:  1797
# imágenes procesadas:  1798
# imágenes procesadas:  1799
# imágenes procesadas:  1800
# imágenes procesadas:  1801
# imágenes procesadas:  1802
# imágenes procesadas:  1803
# imágenes procesadas:  1804
# imágenes procesadas:  1805
# imágenes procesadas:  1806
# imágenes procesadas:  1807
# imágenes procesadas:  1808
# imágenes procesadas:  1809
# imágenes procesadas:  1810
# imágenes procesadas:  1811
# imágenes procesadas:  1812
# imágenes procesadas:  1813
# imágenes procesadas:  1814
# imágenes procesadas:  1815
# imágenes procesadas:  1816
# imágenes procesadas:  1817
# ...
# imágenes procesadas:  9639
# imágenes procesadas:  9640
# imágenes procesadas:  9641
# imágenes procesadas:  9642
# imágenes procesadas:  9643
# imágenes procesadas:  9644
# imágenes procesadas:  9645
# imágenes procesadas:  9646
# imágenes procesadas:  9647
# imágenes procesadas:  9648
# imágenes procesadas:  9649
# imágenes procesadas:  9650
# imágenes procesadas:  9651
# imágenes procesadas:  9652
# imágenes procesadas:  9653
# imágenes procesadas:  9654
# imágenes procesadas:  9655
# imágenes procesadas:  9656
# imágenes procesadas:  9657
# imágenes procesadas:  9658
# imágenes procesadas:  9659
# imágenes procesadas:  9660
# imágenes procesadas:  9661
# imágenes procesadas:  9662
# imágenes procesadas:  9663
# imágenes procesadas:  9664
# imágenes procesadas:  9665
# imágenes procesadas:  9666
# imágenes procesadas:  9667
# imágenes procesadas:  9668
# imágenes procesadas:  9669
# imágenes procesadas:  9670
# imágenes procesadas:  9671
# imágenes procesadas:  9672
# imágenes procesadas:  9673
# imágenes procesadas:  9674
# imágenes procesadas:  9675
# imágenes procesadas:  9676
# imágenes procesadas:  9677
# imágenes procesadas:  9678
# imágenes procesadas:  9679
# imágenes procesadas:  9680
# imágenes procesadas:  9681
# imágenes procesadas:  9682
# imágenes procesadas:  9683
# imágenes procesadas:  9684
# imágenes procesadas:  9685
# imágenes procesadas:  9686
# imágenes procesadas:  9687
# imágenes procesadas:  9688
# imágenes procesadas:  9689
# imágenes procesadas:  9690
# imágenes procesadas:  9691
# imágenes procesadas:  9692
# imágenes procesadas:  9693
# imágenes procesadas:  9694
# imágenes procesadas:  9695
# imágenes procesadas:  9696
# imágenes procesadas:  9697
# imágenes procesadas:  9698
# imágenes procesadas:  9699
# imágenes procesadas:  9700
# imágenes procesadas:  9701
# imágenes procesadas:  9702
# imágenes procesadas:  9703
# imágenes procesadas:  9704
# imágenes procesadas:  9705
# imágenes procesadas:  9706
# imágenes procesadas:  9707
# imágenes procesadas:  9708
# imágenes procesadas:  9709
# imágenes procesadas:  9710
# imágenes procesadas:  9711
# imágenes procesadas:  9712
# imágenes procesadas:  9713
# imágenes procesadas:  9714
# imágenes procesadas:  9715
# imágenes procesadas:  9716
# imágenes procesadas:  9717
# imágenes procesadas:  9718
# imágenes procesadas:  9719
# imágenes procesadas:  9720
# imágenes procesadas:  9721
# imágenes procesadas:  9722
# imágenes procesadas:  9723
# imágenes procesadas:  9724
# imágenes procesadas:  9725
# imágenes procesadas:  9726
# imágenes procesadas:  9727
# imágenes procesadas:  9728
# imágenes procesadas:  9729
# imágenes procesadas:  9730
# imágenes procesadas:  9731
# imágenes procesadas:  9732
# imágenes procesadas:  9733
# imágenes procesadas:  9734
# imágenes procesadas:  9735
# imágenes procesadas:  9736
# imágenes procesadas:  9737
# imágenes procesadas:  9738
# imágenes procesadas:  9739
# imágenes procesadas:  9740
# imágenes procesadas:  9741
# imágenes procesadas:  9742
# imágenes procesadas:  9743
# imágenes procesadas:  9744
# imágenes procesadas:  9745
# imágenes procesadas:  9746
# imágenes procesadas:  9747
# imágenes procesadas:  9748
# imágenes procesadas:  9749
# imágenes procesadas:  9750
# imágenes procesadas:  9751
# imágenes procesadas:  9752
# imágenes procesadas:  9753
# imágenes procesadas:  9754
# imágenes procesadas:  9755
# imágenes procesadas:  9756
# imágenes procesadas:  9757
# imágenes procesadas:  9758
# imágenes procesadas:  9759
# imágenes procesadas:  9760
# imágenes procesadas:  9761
# imágenes procesadas:  9762
# imágenes procesadas:  9763
# imágenes procesadas:  9764
# imágenes procesadas:  9765
# imágenes procesadas:  9766
# imágenes procesadas:  9767
# imágenes procesadas:  9768
# imágenes procesadas:  9769
# imágenes procesadas:  9770
# imágenes procesadas:  9771
# imágenes procesadas:  9772
# imágenes procesadas:  9773
# imágenes procesadas:  9774
# imágenes procesadas:  9775
# imágenes procesadas:  9776
# imágenes procesadas:  9777
# imágenes procesadas:  9778
# imágenes procesadas:  9779
# imágenes procesadas:  9780
# imágenes procesadas:  9781
# imágenes procesadas:  9782
# imágenes procesadas:  9783
# imágenes procesadas:  9784
# imágenes procesadas:  9785
# imágenes procesadas:  9786
# imágenes procesadas:  9787
# imágenes procesadas:  9788
# imágenes procesadas:  9789
# imágenes procesadas:  9790
# imágenes procesadas:  9791
# imágenes procesadas:  9792
# imágenes procesadas:  9793
# imágenes procesadas:  9794
# imágenes procesadas:  9795
# imágenes procesadas:  9796
# imágenes procesadas:  9797
# imágenes procesadas:  9798
# imágenes procesadas:  9799
# imágenes procesadas:  9800
# imágenes procesadas:  9801
# imágenes procesadas:  9802
# imágenes procesadas:  9803
# imágenes procesadas:  9804
# imágenes procesadas:  9805
# imágenes procesadas:  9806
# imágenes procesadas:  9807
# imágenes procesadas:  9808
# imágenes procesadas:  9809
# imágenes procesadas:  9810
# imágenes procesadas:  9811
# imágenes procesadas:  9812
# imágenes procesadas:  9813
# imágenes procesadas:  9814
# imágenes procesadas:  9815
# imágenes procesadas:  9816
# imágenes procesadas:  9817
# imágenes procesadas:  9818
# imágenes procesadas:  9819
# imágenes procesadas:  9820
# imágenes procesadas:  9821
# imágenes procesadas:  9822
# imágenes procesadas:  9823
# imágenes procesadas:  9824
# imágenes procesadas:  9825
# imágenes procesadas:  9826
# imágenes procesadas:  9827
# imágenes procesadas:  9828
# imágenes procesadas:  9829
# imágenes procesadas:  9830
# imágenes procesadas:  9831
# imágenes procesadas:  9832
# imágenes procesadas:  9833
# imágenes procesadas:  9834
# imágenes procesadas:  9835
# imágenes procesadas:  9836
# imágenes procesadas:  9837
# imágenes procesadas:  9838
# imágenes procesadas:  9839
# imágenes procesadas:  9840
# imágenes procesadas:  9841
# imágenes procesadas:  9842
# imágenes procesadas:  9843
# imágenes procesadas:  9844
# imágenes procesadas:  9845
# imágenes procesadas:  9846
# imágenes procesadas:  9847
# imágenes procesadas:  9848
# imágenes procesadas:  9849
# imágenes procesadas:  9850
# imágenes procesadas:  9851
# imágenes procesadas:  9852
# imágenes procesadas:  9853
# imágenes procesadas:  9854
# imágenes procesadas:  9855
# imágenes procesadas:  9856
# imágenes procesadas:  9857
# imágenes procesadas:  9858
# imágenes procesadas:  9859
# imágenes procesadas:  9860
# imágenes procesadas:  9861
# imágenes procesadas:  9862
# imágenes procesadas:  9863
# imágenes procesadas:  9864
# imágenes procesadas:  9865
# imágenes procesadas:  9866
# imágenes procesadas:  9867
# imágenes procesadas:  9868
# imágenes procesadas:  9869
# imágenes procesadas:  9870
# imágenes procesadas:  9871
# imágenes procesadas:  9872
# imágenes procesadas:  9873
# imágenes procesadas:  9874
# imágenes procesadas:  9875
# imágenes procesadas:  9876
# imágenes procesadas:  9877
# imágenes procesadas:  9878
# imágenes procesadas:  9879
# imágenes procesadas:  9880
# imágenes procesadas:  9881
# imágenes procesadas:  9882
# imágenes procesadas:  9883
# imágenes procesadas:  9884
# imágenes procesadas:  9885
# imágenes procesadas:  9886
# imágenes procesadas:  9887
# imágenes procesadas:  9888
# imágenes procesadas:  9889
# imágenes procesadas:  9890
# imágenes procesadas:  9891
# imágenes procesadas:  9892
# imágenes procesadas:  9893
# imágenes procesadas:  9894
# imágenes procesadas:  9895
# imágenes procesadas:  9896
# imágenes procesadas:  9897
# imágenes procesadas:  9898
# imágenes procesadas:  9899
# imágenes procesadas:  9900
# imágenes procesadas:  9901
# imágenes procesadas:  9902
# imágenes procesadas:  9903
# imágenes procesadas:  9904
# imágenes procesadas:  9905
# imágenes procesadas:  9906
# imágenes procesadas:  9907
# imágenes procesadas:  9908
# imágenes procesadas:  9909
# imágenes procesadas:  9910
# imágenes procesadas:  9911
# imágenes procesadas:  9912
# imágenes procesadas:  9913
# imágenes procesadas:  9914
# imágenes procesadas:  9915
# imágenes procesadas:  9916
# imágenes procesadas:  9917
# imágenes procesadas:  9918
# imágenes procesadas:  9919
# imágenes procesadas:  9920
# imágenes procesadas:  9921
# imágenes procesadas:  9922
# imágenes procesadas:  9923
# imágenes procesadas:  9924
# imágenes procesadas:  9925
# imágenes procesadas:  9926
# imágenes procesadas:  9927
# imágenes procesadas:  9928
# imágenes procesadas:  9929
# imágenes procesadas:  9930
# imágenes procesadas:  9931
# imágenes procesadas:  9932
# imágenes procesadas:  9933
# imágenes procesadas:  9934
# imágenes procesadas:  9935
# imágenes procesadas:  9936
# imágenes procesadas:  9937
# imágenes procesadas:  9938
# imágenes procesadas:  9939
# imágenes procesadas:  9940
# imágenes procesadas:  9941
# imágenes procesadas:  9942
# imágenes procesadas:  9943
# imágenes procesadas:  9944
# imágenes procesadas:  9945
# imágenes procesadas:  9946
# imágenes procesadas:  9947
# imágenes procesadas:  9948
# imágenes procesadas:  9949
# imágenes procesadas:  9950
# imágenes procesadas:  9951
# imágenes procesadas:  9952
# imágenes procesadas:  9953
# imágenes procesadas:  9954
# imágenes procesadas:  9955
# imágenes procesadas:  9956
# imágenes procesadas:  9957
# imágenes procesadas:  9958
# imágenes procesadas:  9959
# imágenes procesadas:  9960
# imágenes procesadas:  9961
# imágenes procesadas:  9962
# imágenes procesadas:  9963
# imágenes procesadas:  9964
# imágenes procesadas:  9965
# imágenes procesadas:  9966
# imágenes procesadas:  9967
# imágenes procesadas:  9968
# imágenes procesadas:  9969
# imágenes procesadas:  9970
# imágenes procesadas:  9971
# imágenes procesadas:  9972
# imágenes procesadas:  9973
# imágenes procesadas:  9974
# imágenes procesadas:  9975
# imágenes procesadas:  9976
# imágenes procesadas:  9977
# imágenes procesadas:  9978
# imágenes procesadas:  9979
# imágenes procesadas:  9980
# imágenes procesadas:  9981
# imágenes procesadas:  9982
# imágenes procesadas:  9983
# imágenes procesadas:  9984
# imágenes procesadas:  9985
# imágenes procesadas:  9986
# imágenes procesadas:  9987
# imágenes procesadas:  9988
# imágenes procesadas:  9989
# imágenes procesadas:  9990
# imágenes procesadas:  9991
# imágenes procesadas:  9992
# imágenes procesadas:  9993
# imágenes procesadas:  9994
# imágenes procesadas:  9995
# imágenes procesadas:  9996
# imágenes procesadas:  9997
# imágenes procesadas:  9998
# imágenes procesadas:  9999
# imágenes procesadas:  10000
# imágenes procesadas:  10001
# imágenes procesadas:  10002
# imágenes procesadas:  10003
# imágenes procesadas:  10004
# imágenes procesadas:  10005
# imágenes procesadas:  10006
# imágenes procesadas:  10007
# imágenes procesadas:  10008
# imágenes procesadas:  10009
# imágenes procesadas:  10010
# imágenes procesadas:  10011
# imágenes procesadas:  10012
# imágenes procesadas:  10013
# imágenes procesadas:  10014
# imágenes procesadas:  10015
# imágenes procesadas:  10016
# imágenes procesadas:  10017
# imágenes procesadas:  10018
# imágenes procesadas:  10019
# imágenes procesadas:  10020
# imágenes procesadas:  10021
# imágenes procesadas:  10022
# imágenes procesadas:  10023
# imágenes procesadas:  10024
# imágenes procesadas:  10025
# imágenes procesadas:  10026
# imágenes procesadas:  10027
# imágenes procesadas:  10028
# imágenes procesadas:  10029
# imágenes procesadas:  10030
# imágenes procesadas:  10031
# imágenes procesadas:  10032
# imágenes procesadas:  10033
# imágenes procesadas:  10034
# imágenes procesadas:  10035
# imágenes procesadas:  10036
# imágenes procesadas:  10037
# imágenes procesadas:  10038
# imágenes procesadas:  10039
# imágenes procesadas:  10040
# imágenes procesadas:  10041
# imágenes procesadas:  10042
# imágenes procesadas:  10043
# imágenes procesadas:  10044
# imágenes procesadas:  10045
# imágenes procesadas:  10046
# imágenes procesadas:  10047
# imágenes procesadas:  10048
# imágenes procesadas:  10049
# imágenes procesadas:  10050
# imágenes procesadas:  10051
# imágenes procesadas:  10052
# imágenes procesadas:  10053
# imágenes procesadas:  10054
# imágenes procesadas:  10055
# imágenes procesadas:  10056
# imágenes procesadas:  10057
# imágenes procesadas:  10058
# imágenes procesadas:  10059
# imágenes procesadas:  10060
# imágenes procesadas:  10061
# imágenes procesadas:  10062
# imágenes procesadas:  10063
# imágenes procesadas:  10064
# imágenes procesadas:  10065
# imágenes procesadas:  10066
# imágenes procesadas:  10067
# imágenes procesadas:  10068
# imágenes procesadas:  10069
# imágenes procesadas:  10070
# imágenes procesadas:  10071
# imágenes procesadas:  10072
# imágenes procesadas:  10073
# imágenes procesadas:  10074
# imágenes procesadas:  10075
# imágenes procesadas:  10076
# imágenes procesadas:  10077
# imágenes procesadas:  10078
# imágenes procesadas:  10079
# imágenes procesadas:  10080
# imágenes procesadas:  10081
# imágenes procesadas:  10082
# imágenes procesadas:  10083
# imágenes procesadas:  10084
# imágenes procesadas:  10085
# imágenes procesadas:  10086
# imágenes procesadas:  10087
# imágenes procesadas:  10088
# imágenes procesadas:  10089
# imágenes procesadas:  10090
# imágenes procesadas:  10091
# imágenes procesadas:  10092
# imágenes procesadas:  10093
# imágenes procesadas:  10094
# imágenes procesadas:  10095
# imágenes procesadas:  10096
# imágenes procesadas:  10097
# imágenes procesadas:  10098
# imágenes procesadas:  10099
# imágenes procesadas:  10100
# imágenes procesadas:  10101
# imágenes procesadas:  10102
# imágenes procesadas:  10103
# imágenes procesadas:  10104
# imágenes procesadas:  10105
# imágenes procesadas:  10106
# imágenes procesadas:  10107
# imágenes procesadas:  10108
# imágenes procesadas:  10109
# imágenes procesadas:  10110
# imágenes procesadas:  10111
# imágenes procesadas:  10112
# imágenes procesadas:  10113
# imágenes procesadas:  10114
# imágenes procesadas:  10115
# imágenes procesadas:  10116
# imágenes procesadas:  10117
# imágenes procesadas:  10118
# imágenes procesadas:  10119
# imágenes procesadas:  10120
# imágenes procesadas:  10121
# imágenes procesadas:  10122
# imágenes procesadas:  10123
# imágenes procesadas:  10124
# imágenes procesadas:  10125
# imágenes procesadas:  10126
# imágenes procesadas:  10127
# imágenes procesadas:  10128
# imágenes procesadas:  10129
# imágenes procesadas:  10130
# imágenes procesadas:  10131
# imágenes procesadas:  10132
# imágenes procesadas:  10133
# imágenes procesadas:  10134
# imágenes procesadas:  10135
# imágenes procesadas:  10136
# imágenes procesadas:  10137
# imágenes procesadas:  10138
# imágenes procesadas:  10139
# imágenes procesadas:  10140
# imágenes procesadas:  10141
# imágenes procesadas:  10142
# imágenes procesadas:  10143
# imágenes procesadas:  10144
# imágenes procesadas:  10145
# imágenes procesadas:  10146
# imágenes procesadas:  10147
# imágenes procesadas:  10148
# imágenes procesadas:  10149
# imágenes procesadas:  10150
# imágenes procesadas:  10151
# imágenes procesadas:  10152
# imágenes procesadas:  10153
# imágenes procesadas:  10154
# imágenes procesadas:  10155
# imágenes procesadas:  10156
# imágenes procesadas:  10157
# imágenes procesadas:  10158
# imágenes procesadas:  10159
# imágenes procesadas:  10160
# imágenes procesadas:  10161
# imágenes procesadas:  10162
# imágenes procesadas:  10163
# imágenes procesadas:  10164
# imágenes procesadas:  10165
# imágenes procesadas:  10166
# imágenes procesadas:  10167
# imágenes procesadas:  10168
# imágenes procesadas:  10169
# imágenes procesadas:  10170
# imágenes procesadas:  10171
# imágenes procesadas:  10172
# imágenes procesadas:  10173
# imágenes procesadas:  10174
# imágenes procesadas:  10175
# imágenes procesadas:  10176
# imágenes procesadas:  10177
# imágenes procesadas:  10178
# imágenes procesadas:  10179
# imágenes procesadas:  10180
# imágenes procesadas:  10181
# imágenes procesadas:  10182
# imágenes procesadas:  10183
# imágenes procesadas:  10184
# imágenes procesadas:  10185
# imágenes procesadas:  10186
# imágenes procesadas:  10187
# imágenes procesadas:  10188
# imágenes procesadas:  10189
# imágenes procesadas:  10190
# imágenes procesadas:  10191
# imágenes procesadas:  10192
# imágenes procesadas:  10193
# imágenes procesadas:  10194
# imágenes procesadas:  10195
# imágenes procesadas:  10196
# imágenes procesadas:  10197
# imágenes procesadas:  10198
# imágenes procesadas:  10199
# imágenes procesadas:  10200
# imágenes procesadas:  10201
# imágenes procesadas:  10202
# imágenes procesadas:  10203
# imágenes procesadas:  10204
# imágenes procesadas:  10205
# imágenes procesadas:  10206
# imágenes procesadas:  10207
# imágenes procesadas:  10208
# imágenes procesadas:  10209
# imágenes procesadas:  10210
# imágenes procesadas:  10211
# imágenes procesadas:  10212
# imágenes procesadas:  10213
# imágenes procesadas:  10214
# imágenes procesadas:  10215
# imágenes procesadas:  10216
# imágenes procesadas:  10217
# imágenes procesadas:  10218
# imágenes procesadas:  10219
# imágenes procesadas:  10220
# imágenes procesadas:  10221
# imágenes procesadas:  10222

# %%
print('Guardando imágenes en labeled_test')
imgNumber = 0
for img in os.listdir('./test'):
  print(img)
for img in os.listdir('./test'):
  imgNumber = imgNumber + 1
  print('imágenes procesadas: ', imgNumber)
  imgName = img.split('.')[0]               # convierte '0913209.jpg' en '0913209'
  label = naming_dict[str(imgName)]         # obtiene la raza del diccionario
  counting_dict[label] += 1                 # aumenta la cuenta en el contador
  path = os.path.join('./test', img)
  saveName = './labeled_test/' + label + '-' + str(counting_dict[label]) + '.jpg' # nuevo nombre con raza y número
  image_data = np.array(Image.open(path))
  imageio.imwrite(saveName, image_data)     # guarda la imagen con el nuevo nombre
# Out:
# Guardando imágenes en labeled_test
# 50f60661565a02c5b96f446f089832e6.jpg
# 99bd95316f9796c59072e84932ad33f9.jpg
# c1d8d7185a8ddfc01b0625ddadfbd3b3.jpg
# c174cfe16227d0d75aabe817a9bef945.jpg
# c364569a4a1eba0dd82f4ae244e60aeb.jpg
# 31c45f6f4b1a1dd82a30541a25c2ad09.jpg
# faaf9144e28a76de76ab05c59354f0fb.jpg
# fc29d76d1e3cd3478e9c3121fa50749a.jpg
# b081d636dd4407059f69622ce2d36362.jpg
# 84e3a6a1d53e886d97f65411489969f0.jpg
# 6e01c54252cfc40ecdfde9612d9e6414.jpg
# 93fa4194758960a2fffec91162579467.jpg
# 8651880bfa690882f2589c856fdea161.jpg
# bdd302682f88523977c4f149d6f64224.jpg
# e52a4321a8cb0dd3bcc8f4a68b75eee7.jpg
# e68da487dabcd11874830a177e8b6218.jpg
# 27856322e5bd7791bb7c6d5bd31fd7c4.jpg
# 4384fc6887440d1d46dafbd0a6bdad71.jpg
# ec036cf752a803815c0e8ecc6601b0e3.jpg
# 66479e171fbbd6f874e53c3a0864be1d.jpg
# 4338b655b34c0548b089958e1574d7f1.jpg
# 0d81ae5c4b549b678c83b83f5fbccbbb.jpg
# 2e66e5efdcb7043a05be411148971b79.jpg
# 9cf1938e43a7489a20a0960e359cb68d.jpg
# 85bb38d45f1efff6bc45453df671710a.jpg
# e50319e7efc447bb684fbfdbed3ff041.jpg
# ade72cfdf755a13daac2355904cb0e29.jpg
# 0fc0f2141b0ccaf394c6ff12948cd952.jpg
# c009ab76e918906ae1ce1e582792da34.jpg
# 255977d481d1dd7ce84eec60328dfaa0.jpg
# 152d976d1498996b68a2ad4c1fba695f.jpg
# 090179e04f4d8bf313d0fc97c1879b3f.jpg
# 6038406f41bc0e669f4226c5e85dbcd0.jpg
# 6b4cbaf60d7ab38c6ffa434bbfa81d96.jpg
# e291c3955198350ab26495e9290dbe34.jpg
# imágenes procesadas:  1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ee1e9186cfd1> in <module>()
#       7   print('imágenes procesadas: ', imgNumber)
#       8   imgName = img.split('.')[0]               # convierte '0913209.jpg' en '0913209'
# ----> 9   label = naming_dict[str(imgName)]         # obtiene la raza del diccionario
#      10   counting_dict[label] += 1                 # aumenta la cuenta en el contador
#      11   path = os.path.join('./test', img)
#
# KeyError: '50f60661565a02c5b96f446f089832e6'

# %% [markdown]
# #### Modificar el tamaño de las imágenes

# %% [markdown]
# ##### Estadísticas de los tamaños de las imágenes
#
# Al ser las imágenes parte del dataset de imagenet, cada imagen tiene un tamaño distinto. Por lo que en la siguiente celda se calculan ciertas estadísticas con respecto a los tamaños:
#  - Altura promedio
#  - Altura máxima
#  - Alturna mínima
#  - Ancho promedio
#  - Ancho máximo
#  - Ancho mínimo
#
#  Esto servirá para establecer los tamaño finales de las imágenes de entrada.

# %%
DIR = './train'

def get_size_statistics():
    heights = []
    widths = []
    img_count = 0
    for img in os.listdir(DIR):
        path = os.path.join(DIR, img)
        if "DS_Store" not in path:
            data = np.array(Image.open(path))
            heights.append(data.shape[0])
            widths.append(data.shape[1])
            img_count += 1
    avg_height = sum(heights) / len(heights)
    avg_width = sum(widths) / len(widths)
    print("Average Height: " + str(avg_height))
    print("Max Height: " + str(max(heights)))
    print("Min Height: " + str(min(heights)))
    print('\n')
    print("Average Width: " + str(avg_width))
    print("Max Width: " + str(max(widths)))
    print("Min Width: " + str(min(widths)))

get_size_statistics()

# %%
def label_img(name):
    word_label = name.split('-')[0]
    if word_label == 'golden_retriever': return [0, 0]
    elif word_label == 'shetland_sheepdog' : return [1, 0]
    return [0, 1]

# %% [markdown]
# ##### Modificación del tamaño de las imágenes y data augmentation
# Considerando los resultados de las estadísticas, finalmente se usará por diseño un tamaño de 300 x 300 para las imágenes de entrada. La celda siguiente realiza el trabajo de conversión de tamaño para todas las imágenes y además realiza un aumento de datos, al realizar un espejado de las imágenes de entrenamiento, para tener el doble de imágenes y obtener una mejor performace.

# %%
IMG_SIZE = 300
DIR = 'labeled_train'

def load_training_data():
    contador = 0
    img_count = 0
    train_data = []
    for img in os.listdir(DIR):
        label = label_img(img)
        path = os.path.join(DIR, img)
        print('label: ', label)
        if "DS_Store" not in path:
            img = Image.open(path)
            img = img.convert('L')
            img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
            train_data.append([np.array(img), label])

            # Basic Data Augmentation - Horizontal Flipping
            flip_img = Image.open(path)
            flip_img = flip_img.convert('L')
            flip_img = flip_img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
            flip_img = np.array(flip_img)
            flip_img = np.fliplr(flip_img)
            train_data.append([flip_img, label])
            
    shuffle(train_data)
    return train_data

# %% [markdown]
# ##### Preparación de las imágenes de entrenamiento
#
# La siguiente celda ejecuta la función definida en la anterior, cargando la variable *train_data* con las imágenes preprocesadas. Y muestra una en escala de grises.

# %%
train_data = load_training_data()
plt.imshow(train_data[43][0], cmap = 'gist_gray')

# %% [markdown]
# Se generan los arreglos *trainImages* y *trainLabels* a partir de *train_data*. Estos serán usados como entradas para el proceso de entrenamiento del modelo.

# %%
trainImages = np.array([i[0] for i in train_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
trainLabels = np.array([i[1] for i in train_data])

print(trainLabels[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f6ac1c6799cd> in <module>()
# ----> 1 trainImages = np.array([i[0] for i in train_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
#       2 trainLabels = np.array([i[1] for i in train_data])
#       3
#       4 print(trainLabels[:10])
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# ## Arquitectura de la red

# %% [markdown]
# ### Importar los paquetes de Keras a utilizar

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers. normalization import BatchNormalization
import numpy as np
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ### Implementar la arquitectura del modelo
#
# Se implementará un modelo con la siguiente arquitectura:
#
# *Un bloque convolucional estará formado por una capa de convolución, una capa de pooling, y una capa de normalización*
#
# 1. Entrada: 300 x 300
# 2. Primer Bloque convolucional:
# *   Capa convolucional: 32 filtros de 3 x 3
# *   Capa de pooling: MaxPooling de 2 x 2, stride de 1
# *   Activación: ReLU
# 3. Segundo Bloque convolucional:
# *   Capa convolucional: 64 filtros de 3 x 3
# *   Capa de pooling: MaxPooling de 2 x 2, stride de 1
# *   Activación: ReLU
# 4. Tercer Bloque convolucional:
# *   Capa convolucional: 64 filtros de 3 x 3
# *   Capa de pooling: MaxPooling de 2 x 2, stride de 1
# *   Activación: ReLU
# 5. Cuarto Bloque convolucional:
# *   Capa convolucional: 96 filtros de 3 x 3
# *   Capa de pooling: MaxPooling de 2 x 2, stride de 1
# *   Activación: ReLU
# 6. Quinto Bloque convolucional:
# *   Capa convolucional: 32 filtros de 3 x 3
# *   Capa de pooling: MaxPooling de 2 x 2, stride de 1
# *   Activación: ReLU
# 7. Primer Bloque totalmente conectado:
# *   Capa totalmente conectada: 128 neuronas
# *   Activación: ReLU
# 8. Capa de salida: 2 neuronas, regularización Softmax

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Dropout(0.2))
model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(2, activation = 'softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Compilación del modelo
#
# Se realizará la compilación del modelo, utilizando como función de pérdida la definida mediante una entropía cruzada binaria, como optimizador la técnica adam, como métrica, la medida de precisión simple.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ### Entrenamiento del modelo
#
# Se entrena el modelo con los arreglos *trainImages* y *trainLabels* definidos anteriormente, y con los siguientes parámetros:
#
#
# *   Tamaño de batch: 50
# *   Epochs: 5

# %%
model.fit(trainImages, trainLabels, batch_size = 50, epochs = 5, verbose = 1)
# Out:
# Epoch 1/5
# 2000/2000 [==============================] - 13s 6ms/step - loss: nan - acc: 0.0040
# Epoch 2/5
# 2000/2000 [==============================] - 11s 5ms/step - loss: nan - acc: 0.0040
# Epoch 3/5
# 2000/2000 [==============================] - 11s 5ms/step - loss: nan - acc: 0.0040
# Epoch 4/5
# 2000/2000 [==============================] - 11s 5ms/step - loss: nan - acc: 0.0040
# Epoch 5/5
# 2000/2000 [==============================] - 11s 5ms/step - loss: nan - acc: 0.0040

# %% [markdown]
# ### Cargar las imágenes de prueba
#
# Con el modelo entrenado, se cargarán las imágenes de prueba en el arreglo *test_data* a partir del cual, con el mismo método que para las imágenes de entrenamiento, se obtendrán los arreglos de *testImages* y *testLabels* para evaluar el modelo.

# %%
# Test on Test Set
IMG_SIZE = 300
TEST_DIR = './test'
def load_test_data():
    test_data = []
    for img in os.listdir(TEST_DIR):
        label = label_img(img)
        path = os.path.join(TEST_DIR, img)
        print('img: ', img)
        print('label: ', label)
        if "DS_Store" not in path:
            img = Image.open(path)
            img = img.convert('L')
            img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
            test_data.append([np.array(img), label])
    shuffle(test_data)
    return test_data


test_data = load_test_data()    
plt.imshow(test_data[10][0], cmap = 'gist_gray')
# Out:
# img:  50f60661565a02c5b96f446f089832e6.jpg
# label:  [0, 1]
# img:  99bd95316f9796c59072e84932ad33f9.jpg
# label:  [0, 1]
# img:  c1d8d7185a8ddfc01b0625ddadfbd3b3.jpg
# label:  [0, 1]
# img:  c174cfe16227d0d75aabe817a9bef945.jpg
# label:  [0, 1]
# img:  c364569a4a1eba0dd82f4ae244e60aeb.jpg
# label:  [0, 1]
# img:  31c45f6f4b1a1dd82a30541a25c2ad09.jpg
# label:  [0, 1]
# img:  faaf9144e28a76de76ab05c59354f0fb.jpg
# label:  [0, 1]
# img:  fc29d76d1e3cd3478e9c3121fa50749a.jpg
# label:  [0, 1]
# img:  b081d636dd4407059f69622ce2d36362.jpg
# label:  [0, 1]
# img:  84e3a6a1d53e886d97f65411489969f0.jpg
# label:  [0, 1]
# img:  6e01c54252cfc40ecdfde9612d9e6414.jpg
# label:  [0, 1]
# img:  93fa4194758960a2fffec91162579467.jpg
# label:  [0, 1]
# img:  8651880bfa690882f2589c856fdea161.jpg
# label:  [0, 1]
# img:  bdd302682f88523977c4f149d6f64224.jpg
# label:  [0, 1]
# img:  e52a4321a8cb0dd3bcc8f4a68b75eee7.jpg
# label:  [0, 1]
# img:  e68da487dabcd11874830a177e8b6218.jpg
# label:  [0, 1]
# img:  27856322e5bd7791bb7c6d5bd31fd7c4.jpg
# label:  [0, 1]
# img:  4384fc6887440d1d46dafbd0a6bdad71.jpg
# label:  [0, 1]
# img:  ec036cf752a803815c0e8ecc6601b0e3.jpg
# label:  [0, 1]
# img:  66479e171fbbd6f874e53c3a0864be1d.jpg
# label:  [0, 1]
# img:  4338b655b34c0548b089958e1574d7f1.jpg
# label:  [0, 1]
# img:  0d81ae5c4b549b678c83b83f5fbccbbb.jpg
# img:  47f9911df0b2f8c15e7af917cb3e1701.jpg
# label:  [0, 1]
# img:  85c9d2802ea11ac1baa5f941f60f046b.jpg
# label:  [0, 1]
# img:  9feec66fed6fffc8139af290c04244b8.jpg
# label:  [0, 1]
# img:  b4cc00474a2631ce06ea48e088d1d92d.jpg
# label:  [0, 1]
# img:  7c742720b1272e0e76ca1a5a0eb768a8.jpg
# label:  [0, 1]
# img:  10cd1f206da577eb0ef2ba6ce012b385.jpg
# label:  [0, 1]
# img:  4e714daf29f840c297efaf7cedb2c1e4.jpg
# label:  [0, 1]
# img:  ffd06687c72445b0c6e8a130a0a8711a.jpg
# label:  [0, 1]
# img:  528f88ec0b2777c70694d7c776733e56.jpg
# label:  [0, 1]
# img:  819b75579613e99d024dc42461146154.jpg
# label:  [0, 1]
# img:  efa05bbbd2e169dc723df1a43ff0e1bb.jpg
# label:  [0, 1]
# img:  77a177e121cd8428dd5875c1ddc02b35.jpg
# label:  [0, 1]
# img:  819632ba0fb41691945bd56bfadc0f09.jpg
# label:  [0, 1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3e111b8670f8> in <module>()
#      17
#      18
# ---> 19 test_data = load_test_data()
#      20 plt.imshow(test_data[10][0], cmap = 'gist_gray')
#
# <ipython-input-15-3e111b8670f8> in load_test_data()
#       9         print('label: ', label)
#      10         if "DS_Store" not in path:
# ---> 11             img = Image.open(path)
#      12             img = img.convert('L')
#      13             img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2537         exclusive_fp = True
#    2538
# -> 2539     prefix = fp.read(16)
#    2540
#    2541     preinit()
#
# KeyboardInterrupt:

# %%
testImages = np.array([i[0] for i in test_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
testLabels = np.array([i[1] for i in test_data])

loss, acc = model.evaluate(testImages, testLabels, verbose = 0)
print(acc * 100)

# %% [markdown]
# ## Tarea: Mejorar el modelo
#
# Despues de haber obtenido una performance de aproximadamente el 75 %, existe lugar para mejorar el modelo. Se proponen 5 estrategias para realizarlo, aunque se puede usar cualquier otro método y/o una combinación de los propuestos.
#
# 1. Agregar más Dropout para evitar un overfitting en los datos de entrenamiento.
# 2. Modificar los parámetros de la red convolucional: agregar o quitar capas, modificar el número y tamaño de los filtros, o cambiar las funciones de activación. *Tener en cuenta los tamaños de los feature maps si se decide cambiar el número y tamaño de filtros*
# 3. Alterar la red totalmente conectada: agregando o quitando capas y/o cambiando el número de neuronas.
# 4. Aumento de datos: Durante el entrenamiento se utilizó una técnica básica de aumento de datos, un movimiento horizontal. Se pueden probar otros métodos tales como: otros movimientos, cambiar el tamaño, cambiar escalas de colores, entre otros.
# 5. Cortar las imágenes para obtener solo perros. El dataset de entrenamiento contiene diferentes imágenes donde aparecen perros. Sin embargo, en la misma imagen, aparecen otros objetos o elementos que pueden llevar a la red a confundir que detalles elementales conforman un perro. Una propuesta para mejorar sería corregir ciertas imagenes para solo clasificar imagenes de perros y no todo el resto.

# %%
## Todo: Realizar las mejores en esta celda, o modificar las celdas correspondientes y ordenarlas de manera que se deba correr el Notebook una sola vez. Se puede probar esto con yendo a Entorno de ejecución > Ejecutar todas
